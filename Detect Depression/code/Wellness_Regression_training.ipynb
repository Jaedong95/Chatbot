# %%
import os 
import random
import torch
import numpy as np
import copy 
import json
import argparse 
import glob 
import argparse
import json

from torch import nn
from torch.utils.data import TensorDataset
from attrdict import AttrDict
from scipy.stats import pearsonr, spearmanr
from seqeval import metrics as seqeval_metrics
from sklearn import metrics as sklearn_metrics
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
# from fastprogress.fastprogress import master_bar, progress_bar
from transformers import (
    AdamW,
    get_linear_schedule_with_warmup
)
from src import (
    CONFIG_CLASSES,
    TOKENIZER_CLASSES,
    MODEL_FOR_REGRESSION,
    set_seed
)

from processor import seq_reg_load_and_cache_examples as load_and_cache_examples  
from processor import seq_reg_processors as processors
from processor import seq_reg_output_modes as output_modes

# %% [markdown]
# ### 회귀 모델 3개 이용

# %% [raw]
# train_file: /home/ubuntu/chatbot/dataset/Wellness_KATQN_train.tsv
# dev_file: /home/ubuntu/chatbot/dataset/Wellness_KATQN_val.tsv
# test_file: /home/ubuntu/chatbot/dataset/Wellness_KATQN_test.tsv

# %%
task = 'wellness' 
config_dir = '/home/ubuntu/chatbot/code/config/'
config_file = 'koelectra-base.json'

with open(os.path.join(config_dir, task, config_file)) as f:
    args = AttrDict(json.load(f))

args.output_dir = os.path.join(args.ckpt_dir, args.output_dir)
set_seed(args)

# %%
file_to_read = '/home/ubuntu/chatbot/dataset/Wellness_KATQN_train.tsv'

with open(file_to_read, "r", encoding="utf-8") as f:
    lines = []
    for line in f:
        tmp = line.strip(',') 
        lines.append(tmp[:-1]) 

examples = [] 
set_type = 'train'

for (i, line) in enumerate(lines[1:]):
    line = line.split("\t")
    guid = "%s-%s" % (set_type, i)
    text_a = line[1]
    label = int(line[2])

text_a, label
# Out:
# ('10', 10)

# %%
processor = processors[args.task](args) 
processor.get_examples('train')
# Out:
# [{
#    "guid": "train-0",
#    "label": "70",
#    "text_a": "\ubb34\ub9ac\ud55c \uac83\ub3c4 \uc544\ub2cc\ub370 \ubab8\uc774 \ucc98\uc9c4\ub2e4",
#    "text_b": null
#  },
#  {
#    "guid": "train-1",
#    "label": "5",
#    "text_a": "\uc774\ub7f4 \uac70\uba74 \uc65c \ub098\ub97c \ub0b3\uc740 \uac74\uc9c0.. \ubaa8\ub974\uaca0\uc5b4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-2",
#    "label": "70",
#    "text_a": "\uc18c\ud654\uac00 \uc548 \ub418\ub2c8\uae4c \uc8fd\uc5b4\ubc84\ub9ac\uace0 \uc2f6\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-3",
#    "label": "10",
#    "text_a": "\uadf8 \ub2f9\uc2dc\uc5d0 \uc81c\uac00 \uc544\uc8fc \uc8fd\uace0 \uc2f6\uc5c8\ub2e4\ub294 \uac83\ubc16\uc5d0\ub294 \uc0dd\uac01\uc774 \uc548 \ub098\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-4",
#    "label": "90",
#    "text_a": "\uc9d1\uc911\ub825\uc774 \uc810\uc810 \ub5a8\uc5b4\uc9c0\uace0 \uc788\uc5b4\uc694",
#    "text_b": null
#  },
#  {
#    "guid": "train-5",
#    "label": "70",
#    "text_a": "\uc2ac\ub7fc\ud504 \ub54c\ubb38\uc5d0 \uc544\ubb34\uac83\ub3c4 \ubabb\ud558\uace0 \uadf8\ub798\uc11c \ub354 \uc2ac\ub7fc\ud504\uac00 \uc624\uace0 \uc644\uc804 \uc545\uc21c\ud658\uc774\uc57c",
#    "text_b": null
#  },
#  {
#    "guid": "train-6",
#    "label": "90",
#    "text_a": "\uc815\uae30\uac80\uc9c4 \ub2e4\ub140\uc624\uba74 \uc2ac\ub7fc\ud504\ub97c \uacaa\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-7",
#    "label": "20",
#    "text_a": "\uadfc\ub370 \uc804\ud600 \uc704\ub85c \uc548 \ub418\uace0 \uadf8\ub0e5 \ub2e4 \ud3ec\uae30\ud574\ubc84\ub9ac\uace0 \uc2f6\uc5b4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-8",
#    "label": "90",
#    "text_a": "\uaca8\uc6b8 \ub418\uba74 \ub354 \ucc0c\ub294 \uac83 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-9",
#    "label": "90",
#    "text_a": "\uadf8 \uc774\ud6c4\ub85c\ub3c4 \uc6b0\uc6b8\ud568\uc740 \ud56d\uc0c1 \uc788\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-10",
#    "label": "80",
#    "text_a": "\uc694\uc998 \ub0b4\uac00 \ud560 \uc218 \uc788\ub294 \uc77c\uc774 \uc9d1\uc548\uc77c \ubc16\uc5d0 \uc5c6\ub2e4\ub294 \uc0dd\uac01\ub9cc \ub4e4\uc5b4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-11",
#    "label": "80",
#    "text_a": "\ubb58 \uace0\ub97c\uc9c0 \ub108\ubb34 \uc624\ub798 \uace0\ubbfc\ud55c\ub2e4",
#    "text_b": null
#  },
#  {
#    "guid": "train-12",
#    "label": "70",
#    "text_a": "\uc624\ube60\uac00 \ub108\ubb34 \ubc14\ube60\uc11c \uc785\ub9db\ub3c4 \uc548 \uc0dd\uae30\uace0 \uc6b0\uc6b8\ud55c\uac00 \ubd10",
#    "text_b": null
#  },
#  {
#    "guid": "train-13",
#    "label": "80",
#    "text_a": "\uc637\uc774 \ub2e4 \ub108\ubb34 \ucee4\uc84c\uc744 \uc815\ub3c4\ub85c \uc0b4\uc774 \ube60\uc84c\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-14",
#    "label": "80",
#    "text_a": "\uc800\ub3c4 \uadf8\ub798\uc11c \uadf8\uac70 \ub54c\ubb38\uc5d0 \uc815\ub9d0 \ub9ce\uc774 \ud798\ub4e4\uc5c8\uac70\ub4e0\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-15",
#    "label": "10",
#    "text_a": "\uba58\ud0c8\uc774 \uc0b0\uc0b0\uc870\uac01\uc774 \ub418\ub294 \uac83 \uac19\uace0 \ud798\ub4e4\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-16",
#    "label": "10",
#    "text_a": "\uc790\uafb8\ub9cc \uc6b0\uc6b8\ud574\uc9c0\ub2c8\uae4c \uc544\ubb34\uac83\ub3c4 \ud558\uae30 \uc2eb\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-17",
#    "label": "70",
#    "text_a": "\ub0a8\ud3b8\uc774 \ubb34\uc54c\ucf5c \ub9e5\uc8fc\ub3c4 \ubabb \ub9c8\uc2dc\uac8c \ud558\ub2c8\uae4c \uc18d\uc774 \uc0c1\ud558\uc796\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-18",
#    "label": "10",
#    "text_a": "\ub0a8\ud3b8\uc774 \uc870\uae08\ub9cc \ubb50\ub77c\uace0 \ud574\ub3c4 \ub098\ub97c \uc870\ub871\ud558\ub294 \uac83\ucc98\ub7fc \ub290\uaef4\uc838.",
#    "text_b": null
#  },
#  {
#    "guid": "train-19",
#    "label": "10",
#    "text_a": "\uadf8 \uc21c\uac04\uc5d0 \uc544\ube60\ub97c \uc8fd\uc5ec\ubc84\ub9ac\uace0 \uc2f6\uc5c8\uc5b4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-20",
#    "label": "10",
#    "text_a": "\uc9c4\uc9dc \uc8fd\uc5ec\ubc84\ub9ac\uace0 \uc2f6\uc5c8\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-21",
#    "label": "5",
#    "text_a": "\ub9e8\ub0a0 \uc678\ub86d\ub2e4\ub294 \uc0dd\uac01\uc5d0 \ubc24\ub9c8\ub2e4 \uc7a0\ub3c4 \uc548 \uc624\uace0\u2026 \ub108\ubb34 \ud798\ub4e4\ub2e4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-22",
#    "label": "90",
#    "text_a": "\uc785\ub9db\ub3c4 \uc5c6\uace0 \uba39\uc5b4\uc11c \ubb50\ud558\ub098 \uc2f6\uace0\u2026",
#    "text_b": null
#  },
#  {
#    "guid": "train-23",
#    "label": "90",
#    "text_a": "\uc790\uafb8 \uc758\uc695\uc774 \uc5c6\uc73c\uba74 \uc5b4\ub5a1\ud558\uc9c0",
#    "text_b": null
#  },
#  {
#    "guid": "train-24",
#    "label": "70",
#    "text_a": "\ube48 \uc18d\uc774\ub77c \uc18d\ub3c4 \uc548 \uc88b\uace0\u2026.",
#    "text_b": null
#  },
#  {
#    "guid": "train-25",
#    "label": "10",
#    "text_a": "\ub0b4\uac00 \uc804\ubd80 \ub9dd\uac00\ub728\ub9b0 \uac70 \uac19\uc544\uc11c \uc8c4\ucc45\uac10\uc774 \ub4e4\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-26",
#    "label": "70",
#    "text_a": "\uc694\uc998 \ub108\ubb34 \uc6b0\uc6b8\ud574\uc11c \uacc4\uc18d \ub208\ubb3c\ub9cc \ub098\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-27",
#    "label": "10",
#    "text_a": "\uc790\uafb8 \ud63c\ub098\ub294 \uae30\ubd84\uc774 \ub4e4\uc5b4\uc11c \uc544\ubb34\uac83\ub3c4 \uc548 \ud558\uac8c \ub3fc",
#    "text_b": null
#  },
#  {
#    "guid": "train-28",
#    "label": "80",
#    "text_a": "\ud56d\uc554 \uce58\ub8cc\ub9cc \ubc1b\uace0 \uc624\uba74 \uc18d\uc774 \uba54\uc2a4\uaecd\uace0 \uc18c\ubcc0\ub3c4 \uc790\uc8fc \ub098\uc624\ub294\ub370, \uacac\ub51c \ub9cc\ud574.",
#    "text_b": null
#  },
#  {
#    "guid": "train-29",
#    "label": "5",
#    "text_a": "\uc8fd\uace0 \uc2f6\ub2e8 \ub9d0\uc744 \ubc25\uba39\ub4ef\uc774 \ud574.",
#    "text_b": null
#  },
#  {
#    "guid": "train-30",
#    "label": "90",
#    "text_a": "\ub098\ub77d\uc73c\ub85c \ub5a8\uc5b4\uc9c8 \uac70 \uac19\uc740 \ub290\ub08c",
#    "text_b": null
#  },
#  {
#    "guid": "train-31",
#    "label": "90",
#    "text_a": "\uc785\ub9db\uc774 \ub108\ubb34 \uc5c6\uc5b4\uc11c \uc544\ubb34\uac83\ub3c4 \ubabb \uba39\uc5b4\uc11c \ud798\uc774 \uc5c6\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-32",
#    "label": "10",
#    "text_a": "\uc6d0\ub798 \uc57d \uba39\ub294 \uac78 \uc2eb\uc5b4\ud574\uc11c \ubc84\ud2f0\ub2e4\uac00 \uacb0\uad6d \ub108\ubb34 \ud798\ub4e4\uc5b4\uac00\uc9c0\uace0\u2026",
#    "text_b": null
#  },
#  {
#    "guid": "train-33",
#    "label": "70",
#    "text_a": "\uc785\ub9db\ub3c4 \uc5c6\uc5b4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-34",
#    "label": "80",
#    "text_a": "\uc6b0\uc6b8, \ubd88\uc548 \uac80\uc0ac\uc0c1 \uc810\uc218\uac00 \uc880 \ub192\uac8c \ub098\uc628\uac70\uc57c.",
#    "text_b": null
#  },
#  {
#    "guid": "train-35",
#    "label": "10",
#    "text_a": "\ub208\ucd08\ub9ac\uac00 \ub108\ubb34 \ub530\uac11\uac8c \ub290\uaef4\uc838.",
#    "text_b": null
#  },
#  {
#    "guid": "train-36",
#    "label": "5",
#    "text_a": "\uc5bc\uad74 \ub54c\ubb38\uc5d0 \uba74\uc811\uc5d0\uc11c \ub5a8\uc5b4\uc9c0\ub294 \uac74\uac00.",
#    "text_b": null
#  },
#  {
#    "guid": "train-37",
#    "label": "70",
#    "text_a": "\uacc4\uc18d \uc774\ub7ec\ub2e4 \ubcf4\ub2c8\uae4c \ub418\uac8c \ubb34\uae30\ub825\ud574\uc9c0\ub294 \uac83 \uac19\uc544.",
#    "text_b": null
#  },
#  {
#    "guid": "train-38",
#    "label": "70",
#    "text_a": "\ubbf8\uad6d\uc5d0\uc11c \uc9c0\ub0b4\ub294 \ub3d9\uc548 \uc815\ub9d0 \ud798\ub4e4\uc5c8\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-39",
#    "label": "90",
#    "text_a": "\uc560\uae30 \ub4e4\uc5b4\uc11c\uace0 \ub098\uc11c \ub108\ubb34 \uc7a0\uc744 \ub9ce\uc774 \uc790",
#    "text_b": null
#  },
#  {
#    "guid": "train-40",
#    "label": "70",
#    "text_a": "\ud558\ub8e8 \uc885\uc77c \uc9d1\uc5d0\ub9cc \uc788\uc5c8\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-41",
#    "label": "20",
#    "text_a": "\uc81c\ucd08\uc81c\ub3c4 \uba39\uace0 \uc218\uba74\uc81c\ub3c4 30\uc54c\uc744 \ud55c\ubc88\uc5d0 \uba39\uc5c8\uc5b4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-42",
#    "label": "90",
#    "text_a": "\uba4d\ud574\uc11c \uc544\ubb34 \uc0dd\uac01\ub3c4 \uc548 \ub4e4\uace0\u2026",
#    "text_b": null
#  },
#  {
#    "guid": "train-43",
#    "label": "70",
#    "text_a": "\uc9d1\uc911\uc774 \uc548\ub3fc\uc11c \ucc45\ub3c4 20\ubd84 \uc77d\uace0 \ubabb \uc77d\uaca0\uace0 \ub2f5\ub2f5\ud574 ",
#    "text_b": null
#  },
#  {
#    "guid": "train-44",
#    "label": "70",
#    "text_a": "\uc218\uba74 \uc591\uc774 \ud655 \uc904\uc5c8\ub124",
#    "text_b": null
#  },
#  {
#    "guid": "train-45",
#    "label": "90",
#    "text_a": "\ud654\uc7a5\uc2e4 \uac08 \ub54c\ub791 \ubc25 \uba39\uc744 \ub54c\ub9cc \ubc29 \ubc16\uc73c\ub85c \ub098\uc640\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-46",
#    "label": "70",
#    "text_a": "\uc18d\uc774 \uba54\uc2a4\uaebc\uc6cc\uc11c \uaf2d \ud1a0\ud560 \uac83 \uac19\uc558\uc5b4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-47",
#    "label": "10",
#    "text_a": "\ubcd1\uc6d0 \uac00\uc11c \uc9c4\ub8cc \ubc1b\uc744 \ub54c \ud2b9\ud788 \ub098\ub97c \ubb34\uc2dc\ud558\ub294 \ub290\ub08c\uc774 \ub9ce\uc774 \ub4e4\uc5b4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-48",
#    "label": "90",
#    "text_a": "\uc18c\ud30c\uc5d0 \ub298\uc5b4\uc838\uc11c TV\ub9cc \ubcf4\uc9c0",
#    "text_b": null
#  },
#  {
#    "guid": "train-49",
#    "label": "10",
#    "text_a": "\uac00\uc2b4\uc774 \ubbf8\uc5b4\uc9c0\uace0 \ubaa8\ub4e0 \uac8c \ub2e4 \ub0b4 \uc798 \ubabb \uac19\uc544\uc694",
#    "text_b": null
#  },
#  {
#    "guid": "train-50",
#    "label": "20",
#    "text_a": "\ubb54\uac00 \uc774\ub807\uac8c \uc0dd\uac01\ud558\ub294 \uac70 \ubcf4\uba74 \ub0b4\uac00 \ub108\ubb34 \uc5c4\uc0b4 \ubd80\ub9ac\ub294 \uac83 \uac19\uc544\uc11c \ud55c\uc2ec\ud558\ub2e4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-51",
#    "label": "80",
#    "text_a": "\uc2dd\uc0ac\ub7c9\uc774 \uc2ec\uac01\ud558\uac8c \uc904\uc5c8\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-52",
#    "label": "70",
#    "text_a": "\uc544\uce68\uc5d0 \ub208 \ub730 \ub54c\uac00 \uc81c\uc77c \ud798\ub4e4\uc5c8\ub358 \uac83 \uac19\uc544.",
#    "text_b": null
#  },
#  {
#    "guid": "train-53",
#    "label": "5",
#    "text_a": "\uc608\uc804\ubd80\ud130 \uc8fd\uace0 \uc2f6\ub2e4\ub294 \uc0dd\uac01\uc744 \ub9ce\uc774 \ud588\uc5b4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-54",
#    "label": "90",
#    "text_a": "\uadf8\ub550 \uc815\ub9d0 \uc815\uc2e0\uc801\uc73c\ub85c, \uc721\uccb4\uc801\uc73c\ub85c \ud798\ub4e4\uc5c8\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-55",
#    "label": "70",
#    "text_a": "\uc774\uac70 \ub54c\ubb38\uc5d0 \ub300\uc778\uae30\ud53c\uc99d \uac78\ub9ac\uace0 \uc6b0\uc6b8\uc99d\ub3c4 \ub108\ubb34 \uc2ec\ud588\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-56",
#    "label": "5",
#    "text_a": "\uc560\ub4e4\ub9cc \uc544\ub2c8\uba74 \uadf8\ub0e5 \uc5f0\ud0c4\uac00\uc2a4\ub77c\ub3c4 \ud53c\uc6cc\uc11c \uc8fd\uc5b4\ubc84\ub9ac\uace0 \uc2f6\ub2e4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-57",
#    "label": "80",
#    "text_a": "\uc2dd\uc695\ub3c4 \uc5c6\uace0 \ubb34\uae30\ub825\ud574 \ubbf8\uce58\uaca0\ub2e4",
#    "text_b": null
#  },
#  {
#    "guid": "train-58",
#    "label": "80",
#    "text_a": "\ub3c4\uc800\ud788 \ubc84\ud2f8 \uc790\uc2e0\uc774 \uc5c6\uc5b4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-59",
#    "label": "90",
#    "text_a": "\uc785\ub9db\uc774 \ub108\ubb34 \uc5c6\uc5b4\uc11c \uc544\ubb34\uac83\ub3c4 \ubabb \uba39\uace0 \ubb3c\ub9cc \ub9c8\uc2dc\uace0 \uc788\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-60",
#    "label": "80",
#    "text_a": "\uadf8\ub54c\ubd80\ud130 \ub2ec\ub2ec\uad6c\ub9ac\ub294 \ubb34\uc870\uac74 \uc785\uc5d0 \uc9d1\uc5b4\ub123\uc5c8\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-61",
#    "label": "5",
#    "text_a": "\uc0b4\ucc0c\ub294 \ub0b4\uac00 \ub108\ubb34 \ub054\ucc0d\ud558\uac8c \ub290\uaef4\uc9c0\uba74\uc11c ",
#    "text_b": null
#  },
#  {
#    "guid": "train-62",
#    "label": "80",
#    "text_a": "\uc758\uc695\ub3c4 \uc0ac\ub77c\uc9c0\uace0 \ub0b4 \uc778\uc0dd\ub3c4 \ud5c8\ubb34\ud574",
#    "text_b": null
#  },
#  {
#    "guid": "train-63",
#    "label": "10",
#    "text_a": "\uc5b4\uc81c\ub294 \uc5b4\ub514 \uc544\ud30c\ud2b8\uc5d0\uc11c \ub6f0\uc5b4\ub0b4\ub9b4\uc9c0 \uc0dd\uac01\ud558\uace0 \uc788\ub354\ub77c\uace0.",
#    "text_b": null
#  },
#  {
#    "guid": "train-64",
#    "label": "20",
#    "text_a": "\ud63c\uc790 \uc788\uc73c\uba74 \uafc0\uafc0\ud574",
#    "text_b": null
#  },
#  {
#    "guid": "train-65",
#    "label": "70",
#    "text_a": "\uc5b5\uc9c0\ub85c \uc678\ucd9c\uc744 \ud574\ubd10\ub3c4 \uc5ec\uc804\ud788 \uc758\uc695\uc774 \uc5c6\uace0 \ucd08\uc870\ud55c \uae30\ubd84\uc774\uc57c",
#    "text_b": null
#  },
#  {
#    "guid": "train-66",
#    "label": "90",
#    "text_a": "\uc218\uba74 \uc2dc\uac04 \uae38\uc5c8\ub294\ub370\ub3c4 \uc804\ud600 \uc548 \uc794 \uac83\ub9cc \uac19\uc544\uc694",
#    "text_b": null
#  },
#  {
#    "guid": "train-67",
#    "label": "70",
#    "text_a": "\uc2ec\uac01\ud560 \uc815\ub3c4\ub85c \uc2dd\uc695\uc774 \uc548 \ub4e4\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-68",
#    "label": "10",
#    "text_a": "\ubaa8\ub4e0 \uc77c\uc5d0 \ub2e4 \uc9dc\uc99d\uc774 \ub098",
#    "text_b": null
#  },
#  {
#    "guid": "train-69",
#    "label": "20",
#    "text_a": "\uc808\uce5c\uae4c\uc9c0 \ub098\ub97c \ube44\ub09c\ud558\ub2c8\uae4c \ub0b4\uac00 \ubb34\uac00\uce58\ud55c \uc778\uac04\ucc98\ub7fc \ub290\uaef4\uc84c\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-70",
#    "label": "70",
#    "text_a": "\uc9d1 \uc548\uc5d0\ub9cc \uc788\uc73c\ub2c8\uae4c \ubc43\uc0b4\ub9cc \ub298\uc5b4\ub09c\ub2e4",
#    "text_b": null
#  },
#  {
#    "guid": "train-71",
#    "label": "70",
#    "text_a": "\ud53c\uace4\ud574\uc11c \ud314\ub2e4\ub9ac\uac00 \ubb34\uac70\uc6cc",
#    "text_b": null
#  },
#  {
#    "guid": "train-72",
#    "label": "70",
#    "text_a": "\ub0a8\ud3b8\ub54c\ubb38\uc5d0 \uc790\uafb8 \ub4a4\ucc99\uc5ec",
#    "text_b": null
#  },
#  {
#    "guid": "train-73",
#    "label": "70",
#    "text_a": "\ubc24 \ub0b4\ub0b4 \ub4a4\ucc99\uac70\ub9ac\ub2c8\uae4c \uc0b6\uc774 \ub2e4 \uc6b0\uc6b8\ud574\uc9c0\ub294 \uac83 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-74",
#    "label": "10",
#    "text_a": "\uc65c \uc774\ub9ac \uacf5\ud5c8\ud558\uc9c0",
#    "text_b": null
#  },
#  {
#    "guid": "train-75",
#    "label": "10",
#    "text_a": "\ud589\ubcf5\ud574\uc57c\ub9cc \ud558\ub294 \uc2dc\uae30\uc5d0 \uc2dc\ub301\uc774 \uc790\uafb8 \ubbf8\uc6cc\uc838\uc694",
#    "text_b": null
#  },
#  {
#    "guid": "train-76",
#    "label": "90",
#    "text_a": "\ucc45 \uc77d\uac70\ub098 \uc77c\ud560 \ub54c \ub108\ubb34 \uc0b0\ub9cc\ud55c \uac70 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-77",
#    "label": "80",
#    "text_a": "\uc784\uc2e0\ud558\uace0 \ub098\uc11c \uc9c0\uc625\uc5d0 \uc628 \uac83 \uac19\uc544\uc694",
#    "text_b": null
#  },
#  {
#    "guid": "train-78",
#    "label": "20",
#    "text_a": "\uc5d0\ub4dc\uc6cc\ub4dc \uc99d\ud6c4\uad70\uc774\ub77c\ub294 \uc18c\ub9ac\ub97c \ub4e4\uc73c\ub2c8\uae4c \ub108\ubb34 \uc8c4\ucc45\uac10 \ub290\uaef4",
#    "text_b": null
#  },
#  {
#    "guid": "train-79",
#    "label": "10",
#    "text_a": "\uc0ac\ub78c\ub4e4\uc774 \uccd0\ub2e4\ubcf4\uba74 \ub0b4\uac00 \ubabb\uc0dd\uaca8\uc11c \uadf8\ub7ec\ub098 \ud558\ub294 \ub9c8\uc74c\uc774 \ub4e4\uc5b4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-80",
#    "label": "20",
#    "text_a": "\uc784\uc2e0 \uc911\uc5d0 \ub0a8\ud3b8\uc774 \uc131\ub9e4\ub9e4\ud558\ub294\uac78 \uc54c\uace0 \uc0dd\uc9c0\uc625\uc774 \ub530\ub85c \uc5c6\uc5c8\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-81",
#    "label": "70",
#    "text_a": "\uc9c0\uae08\ub3c4 \uc6b0\uc6b8\ud568\uc740 \uacc4\uc18d \ub9c8\uc74c\uc18d\uc5d0 \ub0a8\uc544\uc788\ub294 \uac83 \uac19\uc544.",
#    "text_b": null
#  },
#  {
#    "guid": "train-82",
#    "label": "10",
#    "text_a": "\uc77c\uc740 \uc313\uc774\ub294\ub370 \ub215\uace0\ub9cc \uc2f6\uace0 \uc544\ubb34\uac83\ub3c4 \ud558\uace0 \uc2f6\uc9c0 \uc54a\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-83",
#    "label": "20",
#    "text_a": "\uadf8\ub0e5 \uc8fd\uc5b4\ubc84\ub9ac\uac8c",
#    "text_b": null
#  },
#  {
#    "guid": "train-84",
#    "label": "90",
#    "text_a": "\uc774\ub7f0 \uc0dd\ud65c\uc744 \ubc18\ubcf5\ud558\ub2e4 \ubcf4\ub2c8\uae4c \ubab8\ubb34\uac8c\uac00 \uc9c4\uc9dc \uc5c4\uccad \ub298\uc5b4\ub09c \uac70\uc608\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-85",
#    "label": "80",
#    "text_a": "\uae30\ubd84\ub3c4 \ud56d\uc0c1 \ub2e4\uc6b4\ub418\uace0 \uc6c3\uc74c\uc774 \uc0ac\ub77c\uc9c4 \uac83 \uac19\uc544.",
#    "text_b": null
#  },
#  {
#    "guid": "train-86",
#    "label": "5",
#    "text_a": "\uadf8\ub0e5 \ud558\ub8e8\ud558\ub8e8\uac00 \uc9c0\uc625 \uac19\uc544\uc694. \uc8fd\uace0 \uc2f6\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-87",
#    "label": "10",
#    "text_a": "\ucc98\uc74c\uc5d0\ub294 \uc544\ubb34\ub807\uc9c0 \uc54a\uc558\ub294\ub370 \uc2dc\uac04\uc774 \uc9c0\ub0a0\uc218\ub85d \uc678\ub86d\ub2e4\ub294 \uac8c \ubb54\uc9c0 \uc54c \uac83 \uac19\uc544.",
#    "text_b": null
#  },
#  {
#    "guid": "train-88",
#    "label": "20",
#    "text_a": "\uc774\ub807\uac8c \uc0ac\ub290\ub2c8 \uadf8\ub0e5 \uc8fd\ub294 \uac8c \ub098\uc740 \uac83 \uac19\uc544\uc11c \uc774\ud2c0 \uc804\uc5d0 \ub2e4\uc2dc \uc790\uc0b4\uc744 \uc0dd\uac01\ud588\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-89",
#    "label": "20",
#    "text_a": "\ud604\uc2e4\uac10\uc774 \uc0dd\uae30\uae30 \uc2dc\uc791\ud558\ub2c8\uae4c \uc88b\uc544\ud558\ub358 \uac70\uc5d0\ub294 \ud765\ubbf8\uac00 \uc548 \uc0dd\uae34\ub2e4",
#    "text_b": null
#  },
#  {
#    "guid": "train-90",
#    "label": "70",
#    "text_a": "\uc2e0\uacbd \uc4f8 \uac8c \ub108\ubb34 \ub9ce\uace0 \ud53c\uace4\ud574\uc11c \uc544\ubb34 \uc77c\ub3c4 \ubabb \ud558\uaca0\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-91",
#    "label": "80",
#    "text_a": "\ub9e8\ub0a0 \uc790\uace0 \uc788\ub294 \uc544\uc774 \ubcf4\uba74 \uc815\ub9d0 \ud558\ub8e8\uc885\uc77c \uc6b0\uc6b8\ud574\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-92",
#    "label": "70",
#    "text_a": "\ubab8\ubb34\uac8c\ub97c \uc7ac\ubcf4\ub2c8\uae4c \ud55c\ub2ec\ub9c8\ub2e4 5\ud0a4\ub85c\uc529 \ucc0c\uace0 \uc788\ub354\ub77c.",
#    "text_b": null
#  },
#  {
#    "guid": "train-93",
#    "label": "70",
#    "text_a": "\uadf8\ub798\ub3c4 \uc5ec\uc804\ud788 \uc6b0\uc6b8\ud55c \ub9c8\uc74c\uc774 \ub4e4\uae34\ud574\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-94",
#    "label": "20",
#    "text_a": "\uc88c\uc808\ub9cc \ud558\uac8c \ub418\ub294\uac83 \uac19\uc544\uc11c \ub108\ubb34 \ud798\ub4e4\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-95",
#    "label": "80",
#    "text_a": "\ucd9c\uadfc\uae38\uc5d0 \ud2b9\ud788 \uc6b8\ub801\uac70\ub9b0\ub2e4",
#    "text_b": null
#  },
#  {
#    "guid": "train-96",
#    "label": "80",
#    "text_a": "\uc2ec\ud558\uac8c \ub9ce\uc774 \uba39\uac8c \ub41c \uac83 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-97",
#    "label": "80",
#    "text_a": "\uc2a4\ud2b8\ub808\uc2a4 \ubc1b\uc73c\ub2c8\uae4c \ubc25 \uba39\ub294 \uac83\ub3c4 \uadc0\ucc2e\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-98",
#    "label": "20",
#    "text_a": "\uadf8\ub798\uc11c \uc8fd\uace0 \uc2f6\ub2e4\ub294 \ub9d0\uc744 \uc785\uc5d0 \ub2ec\uace0 \uc0b4\uc558\uc5b4..",
#    "text_b": null
#  },
#  {
#    "guid": "train-99",
#    "label": "70",
#    "text_a": "\uc694\uc998 \uc790\uafb8\ub9cc \uc2ac\ud37c\uc838\uc694",
#    "text_b": null
#  },
#  {
#    "guid": "train-100",
#    "label": "70",
#    "text_a": "\uc6b0\uc6b8\ud55c \uae30\ubd84\uc774 \uc8fc\uae30\uc801\uc73c\ub85c \uc640.",
#    "text_b": null
#  },
#  {
#    "guid": "train-101",
#    "label": "70",
#    "text_a": "\uc9c0\ub09c\uc8fc\uc5d0 \uadfc\ubb34\ud560 \ub54c\ub294 \ub354 \uc774\uc0c1\uc740 \ud798\ub4e4\uaca0\ub2e4\ub294 \uc0dd\uac01\uc774 \ub4e4\ub9cc\ud07c \ub2f5\ub2f5\ud588\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-102",
#    "label": "10",
#    "text_a": "\ucd08\uae30 \ub54c \uc5c9\uc5c9 \uc6b8\uae30\ub9cc \ud588\ub294\ub370 \uc9c0\uae08\uc740 \uadf8\ub0e5 \ubd84\ub178\uac00 \uc870\uc808 \uc548 \ub3fc",
#    "text_b": null
#  },
#  {
#    "guid": "train-103",
#    "label": "80",
#    "text_a": "\uae30\ubd84\uc774 \ub298 \uc6b0\uc6b8\ud55c \uac74 \uc544\ub2c8\uc5d0\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-104",
#    "label": "90",
#    "text_a": "\uc57d \ub54c\ubb38\uc5d0 \uc7a0\uc740 \ubabb \uc790\uace0 \uc790\uafb8 \uc6b8\uc801\ud574\uc9c4\ub2e4",
#    "text_b": null
#  },
#  {
#    "guid": "train-105",
#    "label": "10",
#    "text_a": "\uc758\uc695\uc774 \uc5c6\ub294 \uac74 \uc5b4\uca54 \uc218 \uc5c6\uc9c0\ub9cc \uc6b0\uc6b8\ud55c \uac74 \uc9c4\uc9dc \ud798\ub4e0 \uac83 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-106",
#    "label": "5",
#    "text_a": "\ud655 \ubaa9\uc774\ub77c\ub3c4 \ub9e4\ub2ec\uae4c\ubd10",
#    "text_b": null
#  },
#  {
#    "guid": "train-107",
#    "label": "80",
#    "text_a": "\uc544\ubb34\uac83\ub3c4 \uc548 \ud558\uace0 \uc0b4\uba74 \ucc9c\uad6d\uc77c \uac83 \uac19\uc544.",
#    "text_b": null
#  },
#  {
#    "guid": "train-108",
#    "label": "5",
#    "text_a": "\ucd9c\uc0b0\uc900\ube44 \ud63c\uc790 \ud558\ub294 \uac83 \uac19\uc544\uc11c \uc4f8\uc4f8\ud558\ub124",
#    "text_b": null
#  },
#  {
#    "guid": "train-109",
#    "label": "10",
#    "text_a": "\uadfc\ub370 \ub098\uc911\uc5d0 \ubc1b\uc744 \uc0c1\ucc98\ubcf4\ub2e4\ub294 \uc678\ub85c\uc6b4\uac8c \ub098\uc544\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-110",
#    "label": "90",
#    "text_a": "\uc694\uc998 \uc9c4\uc9dc \uba38\ub9ac\uac00 \ub108\ubb34 \ubcf5\uc7a1\ud558\uace0 \ud798\ub4e4\ub2e4\u2026",
#    "text_b": null
#  },
#  {
#    "guid": "train-111",
#    "label": "70",
#    "text_a": "\ub300\ud559 \ub2e4\ub2c8\ub294 \ub0b4\ub0b4 \ub108\ubb34 \ud798\ub4e4\uc5c8\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-112",
#    "label": "20",
#    "text_a": "\ub0b4\uac00 \ubb58 \uadf8\ub807\uac8c \uc798\ubabb\ud588\uc744\uae4c.",
#    "text_b": null
#  },
#  {
#    "guid": "train-113",
#    "label": "10",
#    "text_a": "\uc65c \ub09c \uba38\ub9ac\uac00 \uc88b\uc9c0 \uc54a\uc744\uae4c.",
#    "text_b": null
#  },
#  {
#    "guid": "train-114",
#    "label": "70",
#    "text_a": "\uae30\ubd84\uc804\ud658 \uc0bc\uc544 \uce5c\ud55c \uce5c\uad6c\uc640 \ub9cc\ub098\ub3c4 \uae08\uc0c8 \ubb34\uae30\ub825\ud574\uc838",
#    "text_b": null
#  },
#  {
#    "guid": "train-115",
#    "label": "10",
#    "text_a": "\ubc18\ud3ec\ub300\uad50\uc5d0\uc11c \ub6f0\uc5b4\ub0b4\ub9ac\uba74 \ubc14\ub85c \uc8fd\uc744 \uc218 \uc788\uc73c\ub824\ub098?",
#    "text_b": null
#  },
#  {
#    "guid": "train-116",
#    "label": "10",
#    "text_a": "\ub098\ub3c4 \ud55c\uc2ec\uc2a4\ub7fd\uace0 \ub0a8\ud3b8\ub3c4 \ub108\ubb34 \ubbf8\uc6cc.",
#    "text_b": null
#  },
#  {
#    "guid": "train-117",
#    "label": "80",
#    "text_a": "\uc0b4 \uae38\uc774 \ub9c9\ub9c9\ud558\uac8c \ub290\uaef4\uc9c0\ub2c8\uae4c \uc544\uae30\ub3c4 \ud3ec\uae30\ud558\uace0 \uc2f6\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-118",
#    "label": "5",
#    "text_a": "\uad34\ub85c\uc6b4 \uc0dd\uac01\uc774 \uc790\uafb8 \ub4dc\ub2c8\uae4c \ub0b4\uac00 \uc774\uac83\ubc16\uc5d0 \uc548\ub418\ub294 \uc778\uac04\uc778\uac00 \uc2f6\uace0 \uadf8\ub798",
#    "text_b": null
#  },
#  {
#    "guid": "train-119",
#    "label": "10",
#    "text_a": "\ub108\ubb34 \uac00\uc2b4 \uc544\ud504\uace0 \uc8c4\ucc45\uac10\uc5d0 \ube60\uc838\uc11c \ud5c8\uc6b0\uc801\uac70\ub9ac\uac8c \ub418\ub294 \uac83 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-120",
#    "label": "20",
#    "text_a": "\ud604\uc2e4\uc778\uc9c0 \uc54c\uace0 \uc2f6\uc5b4\uc11c \ub208\ub728\uc790\ub9c8\uc790 \uc190\ubaa9\uc744 \uadf8\uc5b4\ubc84\ub838\uc5b4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-121",
#    "label": "20",
#    "text_a": "\uc774\ub807\uac8c \uc6d0\ud558\ub294\ub370\ub3c4 \uc544\uae30\ub97c \uac00\uc9c8 \uc218 \uc5c6\ub2e4\uace0 \uc0dd\uac01\ud558\ub2c8\uae4c \ub9e4\uc77c\uc774 \uc9c0\uc625\uac19\uc558\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-122",
#    "label": "10",
#    "text_a": "\uc9c1\uc7a5\uc744 \uadf8\ub9cc\ub450\ub2c8\uae4c \ub9cc\ub098\ub294 \uc0ac\ub78c\uc774 \uc5c6\uace0 \uc644\uc804 \uc544\uc2f8 \uc778\uc0dd ",
#    "text_b": null
#  },
#  {
#    "guid": "train-123",
#    "label": "70",
#    "text_a": "\ub3c4\ubb34\uc9c0 \uc5b4\ub5bb\uac8c \ud574\uc57c \ud560 \uc9c0 \ubaa8\ub974\uaca0\ub2e4\u2026 \ub108\ubb34 \ud798\ub4e4\uc5b4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-124",
#    "label": "90",
#    "text_a": "\ubab8\uc774 \ucc98\uc9c0\ub2c8\uae4c \uc790\uafb8 \uc131\uc9c8\uc774 \ub098",
#    "text_b": null
#  },
#  {
#    "guid": "train-125",
#    "label": "10",
#    "text_a": "\uacc4\uc808\uc774 \ubc14\ub00c\ub2c8\uae4c \uc6b0\uc6b8\ud55c \uac70 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-126",
#    "label": "90",
#    "text_a": "\uc544\ubb34\uac83\ub3c4 \ud558\uae30 \uc2eb\uc5b4\uc11c \uc8fd\uaca0\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-127",
#    "label": "80",
#    "text_a": "3\uc8fc \uc804\ubd80\ud130 \uc785\ub9db\uc774 \uc5c6\uc5c8\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-128",
#    "label": "80",
#    "text_a": "\uae30\ud615\uc544 \uac80\uc0ac \uacb0\uacfc \uae30\ub2e4\ub9ac\ub294\ub370 \ub108\ubb34 \ucd08\uc870\ud558\uace0 \ubab8\ub3c4 \ubb34\uac81\uac8c \ub290\uaef4\uc838",
#    "text_b": null
#  },
#  {
#    "guid": "train-129",
#    "label": "10",
#    "text_a": "\uc0b4 \ucc0c\uace0 \ubd80\ud130 \uc0ac\ub78c\ub4e4\uc774 \ub098\ub97c \ube44\uc6c3\ub294 \uac83\ucc98\ub7fc \ub290\uaef4\uc84c\uc5b4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-130",
#    "label": "90",
#    "text_a": "\uc120\ubc30\ub4e4\uc774 \ub3d9\uc544\ub9ac \ub4e4\ub77c\uace0 \ud558\ub294 \uac83\ub3c4 \ud558\ub098\ub3c4 \uc548 \uac00\uace0, \uce5c\uad6c\ub4e4\uc774 \ub9db\uc788\ub294 \ubc25\uc9d1 \uc788\ub2e4\uace0 \uadf8\ub7ec\ub294\ub370\ub3c4 \uc804\ud600 \ud765\ubbf8\uac00 \uc548 \uc0dd\uacbc\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-131",
#    "label": "5",
#    "text_a": "\uc774\uc138\uc0c1\uc5d0\uc11c \ub098 \ud63c\uc790\ubfd0\uc778 \uac83 \uac19\uace0 \ud798\ub4e4\uc5b4\uc11c \uc220 \ub9c8\uc168\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-132",
#    "label": "10",
#    "text_a": "\uac11\uc0c1\uc120\uc5d0 \ubb38\uc81c \uc0dd\uacbc\ub2e4\uace0 \ud558\ub2c8\uae4c \uc804\ubd80 \ub0b4 \uc798\ubabb \uac19\uc544\uc11c \uc544\uae30\ud55c\ud14c \ubbf8\uc548\ud558\uace0 \uc8c4\ucc45\uac10 \ub108\ubb34 \uc2ec\ud558\uac8c \ub4e4\uace0\u2026",
#    "text_b": null
#  },
#  {
#    "guid": "train-133",
#    "label": "70",
#    "text_a": "\uba39\uc744 \ub54c \uc624\ud788\ub824 \ubab8\ubb34\uac8c\uac00 \ub354 \uc8fc\ub294 \uac83 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-134",
#    "label": "10",
#    "text_a": "\ub2e8\uc74c\uc2dd\ub3c4 \uc804\ubd80 \ub04a\uc5c8\ub294\ub370 \uc784\ub2f9 \uc7ac\uac80 \ub5a0\uc11c \uce68\uc6b8\ud574",
#    "text_b": null
#  },
#  {
#    "guid": "train-135",
#    "label": "80",
#    "text_a": "\uc9dc\uc99d\ub098\uc11c \ubc30\uac00 \uc548 \uace0\ud30c\ub3c4 \uacc4\uc18d \uba39\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-136",
#    "label": "70",
#    "text_a": "\ud0dc\ub3d9\uc774 \uc904\uc5b4\ub4e0 \uc774\ud6c4\ub85c \ucd08\uc870\ud558\uace0 \uc228 \uc26c\uae30\ub3c4 \uc5b4\ub824\uc6cc",
#    "text_b": null
#  },
#  {
#    "guid": "train-137",
#    "label": "90",
#    "text_a": "\ub0a8\ud3b8\uc740 \ud5c8\ub9ac\ub514\uc2a4\ud06c \uc218\uc220\uc744 \ubc1b\uace0 \uc77c\uc815\ud55c \uc9c1\uc5c5\uc5c6\uc774 \ub9e4\uc77c \uc220\ub9cc \uba39\uace0 \uc9c0\ub0b4\ub294\ub370 \uc81c\uac00 \uc5b4\ub5bb\uac8c \ub9e8\uc815\uc2e0\uc77c \uc218 \uc788\uaca0\uc5b4\uc694..",
#    "text_b": null
#  },
#  {
#    "guid": "train-138",
#    "label": "90",
#    "text_a": "\ub108\ubb34 \ub180\uc544\uc11c \uadf8\ub7f0\uc9c0 \uae00\uc790\uac00 \uba38\ub9ac\uc5d0 \uc548 \ub4e4\uc5b4\uc624\uace0 \uc6b0\uc6b8\ud558\ub2e4",
#    "text_b": null
#  },
#  {
#    "guid": "train-139",
#    "label": "90",
#    "text_a": "\uc8fc\uc704\uc5d0 \uc0ac\ub78c\uc774 \uc5c6\ub2e4\ub294 \uac74 \uc6b0\uc6b8\ud558\uc9c0.",
#    "text_b": null
#  },
#  {
#    "guid": "train-140",
#    "label": "70",
#    "text_a": "\uc0b4\uc774 \ub108\ubb34 \ub9ce\uc774 \ube60\uc838\uc11c \uc637\uc774 \ub9de\ub294 \uac8c \uc5c6\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-141",
#    "label": "10",
#    "text_a": "\uadf8\ub0e5\u2026 \uc774 \uc138\uc0c1\uc774 \ub0a0 \uac00\ub450\uace0 \uad34\ub86d\ud788\ub294 \uac83 \uac19\uc544\uc11c \uc6d0\ub9dd\uc2a4\ub7ec\uc6cc.",
#    "text_b": null
#  },
#  {
#    "guid": "train-142",
#    "label": "10",
#    "text_a": "\ub0b4\uac00 \uc544\ub4e4 \uac00\uc84c\uc73c\uba74 \ub0a8\ud3b8\uc774\ub791 \uc5b4\uba38\ub2c8\ub791 \ud654\ud574\ub97c \ud588\uc744 \ud150\ub370",
#    "text_b": null
#  },
#  {
#    "guid": "train-143",
#    "label": "10",
#    "text_a": "\ud63c\uc790 \uc788\uc73c\uba74 \ud5c8\uc804\ud558\uace0 \uc4f8\uc4f8\ud55c \uae30\ubd84\uc774 \ub4e4\uc5b4\uc694",
#    "text_b": null
#  },
#  {
#    "guid": "train-144",
#    "label": "10",
#    "text_a": "\uc5b4\ub5bb\uac8c \ud574\uc57c \ucc38\ub2f4\ud55c \uac10\uc815\uc774 \ud480\ub9b4 \uc218 \uc788\ub2c8",
#    "text_b": null
#  },
#  {
#    "guid": "train-145",
#    "label": "70",
#    "text_a": "\ubc14\ube60\uc11c \uadf8\ub7f0\uc9c0 \uc0b4\uc774 \ube60\uc9c0\ub294 \uac83 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-146",
#    "label": "80",
#    "text_a": "\uc544\uc774\ub54c\ubb38\uc5d0 \ub0a0\uce74\ub85c\uc6cc\uc84c\uc9c0",
#    "text_b": null
#  },
#  {
#    "guid": "train-147",
#    "label": "80",
#    "text_a": "\ub098\ub294 \ub9e8\ub0a0 \ucc38\uace0\ub9cc \uc0ac\ub294 \uac83 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-148",
#    "label": "70",
#    "text_a": "\uadf8\ub798\uc11c \uc2a4\ud2b8\ub808\uc2a4\ub97c \ub108\ubb34 \ubc1b\uc544\uac00\uc9c0\uad6c \uc6b0\uc6b8\ud574\uc9c0\ub354\ub77c\uad6c.",
#    "text_b": null
#  },
#  {
#    "guid": "train-149",
#    "label": "90",
#    "text_a": "\uc6b4\ub3d9\ub3c4 \ud558\ub294\ub370 \uacc4\uc18d \uac00\ubfd0\ud558\uc9c0\uac00 \uc54a\ub124",
#    "text_b": null
#  },
#  {
#    "guid": "train-150",
#    "label": "10",
#    "text_a": "\uc544\u2026\uc9c4\uc9dc \ub18d\uc57d\uc774\ub77c\ub3c4 \ud0c0\uc11c \uba39\uc5ec\uc57c\ud558\ub098\uc2f6\ub2e4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-151",
#    "label": "10",
#    "text_a": "\ud558\ub8e8 \uc885\uc77c \uc9dc\uc99d\ub9cc \ub0b4\ub2e4\uac00 \ub05d\ub098\ub294 \uac70 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-152",
#    "label": "20",
#    "text_a": "\ub0a8\ud3b8\uc774\ub791 \uc0ac\ub294 \uac8c \ud798\ub4e4\uc5b4\uc11c \uadf8\ub7ac\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-153",
#    "label": "80",
#    "text_a": "\ubc25 \uccad\uc18c \ub2e4 \ud558\uae30 \uc2eb\uace0 \uadf8\ub0e5 \uce5c\uc815 \uac00\uace0 \uc2f6\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-154",
#    "label": "70",
#    "text_a": "\uc0ac\ub294 \uac8c \uc9c0\ub8e8\ud558\ub2e4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-155",
#    "label": "20",
#    "text_a": "\ubaa8\ub4e0 \uac8c \ub2e4 \uaf2c\uc5ec\ubc84\ub9b0 \uac83 \uac19\uc544.",
#    "text_b": null
#  },
#  {
#    "guid": "train-156",
#    "label": "90",
#    "text_a": "\ud3c9\uc18c\uc5d0 \ud56d\uc0c1 \uc6b0\uc6b8\ud558\uace0 \ubd88\uc548\ud574\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-157",
#    "label": "90",
#    "text_a": "\uc6d0\ub798\ub3c4 \uc6b0\uc6b8\uc99d\uc774 \uc880 \uc788\uae34 \ud588\ub294\ub370 \ubc14\ube60\uc11c \uc78a\uace0 \uc9c0\ub0c8\uac70\ub4e0.",
#    "text_b": null
#  },
#  {
#    "guid": "train-158",
#    "label": "5",
#    "text_a": "\ub204\uac00 \uc606\uc5d0 \uc788\ub4e0 \uac04\uc5d0 \uadf8\ub0e5 \uba4d\ud558\uac8c \uc788\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-159",
#    "label": "70",
#    "text_a": "\uadf8\ub7f0\ub370 \ub0b4 \ubb38\uc81c\uc5d0 \ub300\ud574\uc11c\ub294 \ub9d0\ub3c4 \ubabb \ud558\uace0\u2026 \uad1c\ucc2e\uc740 \ucc99 \uc6c3\uace0 \uc788\ub294 \uac8c \ub108\ubb34 \uad34\ub85c\uc6e0\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-160",
#    "label": "20",
#    "text_a": "\ub108\ubb34 \uc774\ub978 \ub098\uc774\uc5d0 \uc784\uc2e0\uc744 \ud55c \uac83 \uac19\uc544\uc11c \uace0\ub3c5\ud55c \uac83 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-161",
#    "label": "20",
#    "text_a": "\uc694\uc998 \ub9e8\ub0a0 \uc790\uc0b4 \uc0dd\uac01 \ud558\uac70\ub4e0\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-162",
#    "label": "5",
#    "text_a": "\uc544\ubb34\ub3c4 \ub098\ub97c \uc751\uc6d0\ud574\uc8fc\ub294 \uc0ac\ub78c\uc774 \uc5c6\uc5c8\uac70\ub4e0.",
#    "text_b": null
#  },
#  {
#    "guid": "train-163",
#    "label": "90",
#    "text_a": "\ubb54\uac00 \uc9d1\uc911\ub825\ub3c4 \ub5a8\uc5b4\uc9c4 \uac83 \uac19\uc544\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-164",
#    "label": "70",
#    "text_a": "\ub0a8\uc790\uce5c\uad6c\ub3c4 \ubabb \ub9cc\ub4e4\uace0, \uce5c\uad6c\ub3c4 \ubabb \ub9cc\ub098\ub294 \uc0c1\ud669\uc774 \ucc98\ub7c9\ud558\uac8c \ub290\uaef4\uc838\uc11c \uc6b0\uc6b8\ud574\uc694. ",
#    "text_b": null
#  },
#  {
#    "guid": "train-165",
#    "label": "70",
#    "text_a": "\ud63c\uc790 \uc788\uc744 \ub54c \ubbf8\uce5c \ub4ef\uc774 \uba39\uc5b4\uc694",
#    "text_b": null
#  },
#  {
#    "guid": "train-166",
#    "label": "80",
#    "text_a": "\uc784\uc6a9\uc774 \uc5b4\ub824\uc6b8 \uc904\uc740 \uc54c\uc558\uc9c0\ub9cc \ub108\ubb34 \ud798\ub4e4\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-167",
#    "label": "70",
#    "text_a": "\uc815\uc2e0\uc801\uc73c\ub85c \ub108\ubb34 \uad34\ub85c\uc6b0\ub2c8\uae4c \uc790\uafb8 \uc220 \ub2f4\ubc30\ub97c \ucc3e\uac8c \ub3fc. \uadf8\ub0e5 \uc5f0\uae30\ucc98\ub7fc \uc0ac\ub77c\uc9c0\uace0 \uc2f6\uc5b4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-168",
#    "label": "90",
#    "text_a": "\uc2ec\uac01\ud558\uac8c \uc2dd\uc695\uc774 \uc5c6\ub294 \uac83 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-169",
#    "label": "80",
#    "text_a": "\uc544\uce68\uc5d0 \uc77c\uc5b4\ub098\ub294 \uc77c\uc774 \uc815\ub9d0 \uc8fd\uae30\ubcf4\ub2e4 \uc2eb\uc740 \uac70\uc57c",
#    "text_b": null
#  },
#  {
#    "guid": "train-170",
#    "label": "10",
#    "text_a": "\ub098\ud55c\ud14c \ud574\uc900 \uac83\ub3c4 \uc5c6\uc73c\uba74\uc11c \uc794\uc18c\ub9ac\ub294 \uc65c \uadf8\ub807\uac8c \uc2ec\ud55c \uac74\ub370?",
#    "text_b": null
#  },
#  {
#    "guid": "train-171",
#    "label": "20",
#    "text_a": "\uc8fd\uace0\uc2f6\uc740\ub370 \uc8fd\uae30\ub294 \ubb34\uc11c\uc6cc\uc11c \uc790\ud574\ub97c \uacc4\uc18d \ud558\ub294 \uac83 \uac19\uc544.",
#    "text_b": null
#  },
#  {
#    "guid": "train-172",
#    "label": "70",
#    "text_a": "\uc778\uac04\uc740 \uc8fd\ub294\ub2e4\ub294 \uac74 \uc774\ub807\uac8c \ud5c8\ubb34\ud558\uad6c\ub098.",
#    "text_b": null
#  },
#  {
#    "guid": "train-173",
#    "label": "70",
#    "text_a": "\uc7a0\uc774 \uc774\ub807\uac8c \uc548 \uc62c \uc218\uac00 \uc788\ub098 \uc2f6\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-174",
#    "label": "10",
#    "text_a": "\uc88b\uc544\ud558\ub294 \uac78 \ud574\ub3c4 \ubaa8\ub4e0 \uac8c \uc9c0\uacb9\uace0 \uc7ac\ubbf8\uc5c6\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-175",
#    "label": "20",
#    "text_a": "\uc5b4\ub5bb\uac8c \ud55c \uc784\uc2e0\uc778\ub370 \uc720\uc0b0\ub418\uba74 \uc9c4\uc9dc \ud5c8\ub9dd\ud558\uace0 \ud654\uac00 \ub0a0 \uac70\uc57c",
#    "text_b": null
#  },
#  {
#    "guid": "train-176",
#    "label": "90",
#    "text_a": "\uc6b0\ub9ac\uc9d1\uc740 \uc65c \ub0a8\ub4e4\ucc98\ub7fc \uc798 \uc0b4\uc9c8 \ubabb \ud560\uae4c \uc6b0\uc6b8\ud558\uae30\ub3c4 \ud558\uace0\u2026",
#    "text_b": null
#  },
#  {
#    "guid": "train-177",
#    "label": "10",
#    "text_a": "\ub098 \ub9d0\uace0 \ub2e4\ub978 \uce5c\uad6c\ub4e4\uc740 \uc131\uc801 \uc798 \ubc1b\uc740 \uac70 \uac19\uc544\uc11c \uc5f4 \ubc1b\uae30\ub3c4 \ud558\uace0\u2026",
#    "text_b": null
#  },
#  {
#    "guid": "train-178",
#    "label": "70",
#    "text_a": "\uc774\uc720\ub3c4 \uc5c6\uc774 \ubc25\ub9db\uc774 \uc5c6\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-179",
#    "label": "5",
#    "text_a": "\uc5bc\uad74\uc774 \ubabb \uc0dd\uaca8\uc11c \uc790\uafb8 \uc774\ub7ec\ub098 \uc2f6\uae30\ub3c4 \ud558\uace0.",
#    "text_b": null
#  },
#  {
#    "guid": "train-180",
#    "label": "10",
#    "text_a": "\uc785\ub367 \ub54c\ubb38\uc5d0 \uc560\uae30\uac00 \ubbf8\uc6cc\uc9c0\uace0 \uc774\ub7f0 \uc790\uc2e0\ud55c\ud14c \uc5b4\uc774\uc5c6\uace0 \uc560\uae30\ud55c\ud14c \ubbf8\uc548\ud574\uc11c \uc8c4\ucc45\uac10 \ub4e4\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-181",
#    "label": "5",
#    "text_a": "\uc721\uc544\ub3c4 \uc800 \ud63c\uc790\ud574\uc11c \ub354 \uc678\ub86d\uace0 \uc9d1\uc548\uc77c\ub3c4 \ud558\uae30 \uc2eb\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-182",
#    "label": "70",
#    "text_a": "\uc778\uc218\uc778\uacc4 \ub2e4 \ud574\ub194\ub3c4 \ud6c4\uc784\uc790\ub4e4\uc774 \uad00\ub46c\uc11c \ud798\uc774 \ube60\uc838",
#    "text_b": null
#  },
#  {
#    "guid": "train-183",
#    "label": "20",
#    "text_a": "\uc810\uc810 \uc18c\uc678\uac10\uc744 \ub290\uaef4",
#    "text_b": null
#  },
#  {
#    "guid": "train-184",
#    "label": "70",
#    "text_a": "\uc9e7\uc73c\uba74 \uc774\uc8fc\u2026. \uae38\uba74 \ub450\uc138\ub2ec... \uc6b0\uc6b8\ud558\uace0 \ubd88\uc548\ud588\uc5b4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-185",
#    "label": "70",
#    "text_a": "\uc9c0\ub09c \ud559\uae30\uc5d0 \uc7a5\ud559\uae08\ub3c4 \ubabb \ubc1b\uc544\uc11c \uc815\ub9d0 \uc8fd\uace0 \uc2f6\uc5c8\uc5b4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-186",
#    "label": "80",
#    "text_a": "\uc774\ub7f0 \uc0dd\uac01 \ub54c\ubb38\uc5d0 \ubc16\uc5d0 \ub098\uac00\ub294\uac8c \ud798\ub4e4\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-187",
#    "label": "20",
#    "text_a": "\ub9c8\uce58 \uac10\uc625 \uc18d\uc5d0 \ud63c\uc790 \uc788\ub294 \uac83 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-188",
#    "label": "70",
#    "text_a": "\ud55c\ub3d9\uc548\uc740 \ub354 \ubc14\uae65\uc73c\ub85c \uc548 \ub098\uac00\uace0 \uc2f6\uc5b4\ud560 \uac83 \uac19\uc544.",
#    "text_b": null
#  },
#  {
#    "guid": "train-189",
#    "label": "70",
#    "text_a": "\uadf8\ub807\uac8c \uba39\uace0 \uc549\uc544\uc11c \uacf5\ubd80\ub9cc \ud558\ub2c8\uae4c \uc0b4\ub3c4 \ub418\uac8c \uca84\uc11c \ub610 \uc2a4\ud2b8\ub808\uc2a4 \ubc1b\uace0\u2026",
#    "text_b": null
#  },
#  {
#    "guid": "train-190",
#    "label": "70",
#    "text_a": "\uc790\ub294 \uac8c \ub108\ubb34 \ud798\ub4e4\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-191",
#    "label": "70",
#    "text_a": "\uc2dc\ub301\uc5d0 \uc788\uc73c\ub2c8\uae4c \uccb4\uc911\uc774 \uc904\uc5c8\ub124",
#    "text_b": null
#  },
#  {
#    "guid": "train-192",
#    "label": "70",
#    "text_a": "\uc9d1\uc5d0\ub9cc \uc788\uc73c\ub2c8\uae4c \ub354 \ud798\uc774 \uc5c6\ub124",
#    "text_b": null
#  },
#  {
#    "guid": "train-193",
#    "label": "70",
#    "text_a": "\ub0b4\uac00 \ucc3d\ud53c\ud574\uc11c \ubc16\uc5d0\uc11c \ub9d0\ub3c4 \ubabb \ud558\uaca0\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-194",
#    "label": "20",
#    "text_a": "\ub2a6\uac8c \uc784\uc2e0\ud55c \ub0b4\uac00 \ubbf8\uc6cc",
#    "text_b": null
#  },
#  {
#    "guid": "train-195",
#    "label": "20",
#    "text_a": "\uacb0\ud63c\ud558\uace0 \ub098\uc11c \uad1c\ud788 \ub0b4 \uc778\uc0dd\ub9dd\uce5c \uac83 \uac19\uace0 \uc4f8\uc4f8\ud574",
#    "text_b": null
#  },
#  {
#    "guid": "train-196",
#    "label": "90",
#    "text_a": "\uc9d1\uc5d0 \uc788\uc73c\uba74 \uad1c\ucc2e\uc544\uc11c \uac70\uc758 \uc9d1\uc5d0\ub9cc \uc788\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-197",
#    "label": "10",
#    "text_a": "\uc0b4\uae30 \uc2eb\uc740\ub370 \uc5b4\ub5a1\ud558\ub0d0",
#    "text_b": null
#  },
#  {
#    "guid": "train-198",
#    "label": "80",
#    "text_a": "\ub108\ubb34 \ucd08\uc870\ud558\uace0 \uc228\uc774 \uac00\ube60\uc11c \uc228 \uc26c\ub294 \ubc29\ubc95\ub3c4 \uc78a\uc5b4\ubc84\ub9b0 \uac70 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-199",
#    "label": "90",
#    "text_a": "\ud558\ub8e8\uc885\uc77c \uad76\ub2e4\uac00 \ud55c \ubc88\uc5d0 \uacfc\uc2dd\uc744 \ud558\uac8c \ub3fc.",
#    "text_b": null
#  },
#  {
#    "guid": "train-200",
#    "label": "20",
#    "text_a": "\uc6cc\ud0b9\ub9d8\uc778 \ub0b4\uac00 \uc2eb\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-201",
#    "label": "70",
#    "text_a": "\uc0b4\ub3c4 \uc5c4\uccad \ube60\uc9c0\uace0 \ub9e8\ub0a0 \uc628\ubab8\uc774 \ud384\ud384 \ub053\uace0 \uc7a5\ub09c \uc544\ub2c8\uc5c8\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-202",
#    "label": "10",
#    "text_a": "\uc544\uae30\uac00 \uc544\ud504\ub2e4\uace0 \ud558\ub2c8\uae4c \ub108\ubb34 \uc808\ub9dd\uc801\uc774\ub354\ub77c\uace0",
#    "text_b": null
#  },
#  {
#    "guid": "train-203",
#    "label": "70",
#    "text_a": "7\uc6d4\ubd80\ud130 \uba39\ub294 \uac78\ub85c \uc2a4\ud2b8\ub808\uc2a4 \ud480\uc5c8\ub358 \uac70 \uac19\uc544.",
#    "text_b": null
#  },
#  {
#    "guid": "train-204",
#    "label": "10",
#    "text_a": "\uc6b0\uc6b8\ud574\uc11c \ud328\ubc30\uac10\uc774 \ub4dc\ub294 \uac78\uae4c",
#    "text_b": null
#  },
#  {
#    "guid": "train-205",
#    "label": "70",
#    "text_a": "\ub0b4 \uc2a4\uc2a4\ub85c\uac00 \ub108\ubb34 \ucabd\ud314\ub824\uc11c \uc8fd\uc744 \uac70 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-206",
#    "label": "10",
#    "text_a": "\ub108\ubb34 \uc6d0\ub9dd\uc2a4\ub7ec\uc6b4\ub370\u2026 \uadf8\ub0e5 \uc5b4\uca54 \uc218 \uc5c6\ub2e4 \ud3ec\uae30\ud558\uac8c \ub418\ub354\ub77c\uad6c\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-207",
#    "label": "10",
#    "text_a": "\ucc28\ub77c\ub9ac \uc8fd\ub294 \uac8c \ub0ab\uc9c0 \uc54a\uc744\uae4c\uc694?",
#    "text_b": null
#  },
#  {
#    "guid": "train-208",
#    "label": "5",
#    "text_a": "\uc790\uafb8 \ube44\uad00\uc801\uc778 \uc0dd\uac01\ub9cc \ud558\uac8c \ub3fc",
#    "text_b": null
#  },
#  {
#    "guid": "train-209",
#    "label": "10",
#    "text_a": "\ubcd1\uc6d0\uc5d0\uc11c \uc758\uc0ac \uc5bc\uad74 \ubcf4\uba74 \uc9dc\uc99d\ub098 \ubbf8\uce58\uaca0\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-210",
#    "label": "10",
#    "text_a": "\ub098\ud55c\ud14c \ub2e8\ub2e8\ud788 \ubbf8\uc6b4 \ud138\uc774 \ubc15\ud614\uc5b4\uc694",
#    "text_b": null
#  },
#  {
#    "guid": "train-211",
#    "label": "70",
#    "text_a": "\uc784\uc2e0\ud55c \ud6c4\ub85c \ud798\uc774 \uc5c6\ub294 \uac70 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-212",
#    "label": "10",
#    "text_a": "\ub0b4 \ud0d3\uc774\ub77c\uace0 \ud558\ub294 \uac8c \uc18d \ud3b8\ud574",
#    "text_b": null
#  },
#  {
#    "guid": "train-213",
#    "label": "10",
#    "text_a": "\ub4a4\uc9c0\uace0 \uc2f6\uc740 \uc0dd\uac01\ub9cc \ub4e4\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-214",
#    "label": "10",
#    "text_a": "\uc544\uae30 \uc783\uace0 \ub0b4\uac00 \ucc38 \uc4f8\ubaa8 \uc5c6\uc774 \ub290\uaef4\uc9c0\ub354\ub77c",
#    "text_b": null
#  },
#  {
#    "guid": "train-215",
#    "label": "5",
#    "text_a": "\ub2e4\ub4e4 \uc65c \ub098\ub97c \ubb34\uc2dc\ud558\ub294 \uac74\uc9c0 \ubaa8\ub974\uaca0\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-216",
#    "label": "90",
#    "text_a": "\uc65c \uc774\ub807\uac8c \uc785\ub9db\uc774 \uc5c6\ub294\uc9c0 \uc544\ub2c8?",
#    "text_b": null
#  },
#  {
#    "guid": "train-217",
#    "label": "10",
#    "text_a": "\ub9c8\uc74c\uc774 \ubb34\ub108\uc9c0\ub294 \uac83 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-218",
#    "label": "20",
#    "text_a": "\ub0b4\uac00 \uc774 \uc138\uc0c1\uc5d0 \uc0b4\uc544\uc57c \ud560 \uc758\ubbf8\uac00 \uc788\uc744\uae4c?",
#    "text_b": null
#  },
#  {
#    "guid": "train-219",
#    "label": "90",
#    "text_a": "\ubb50 \ud558\uace0 \uc2f6\uc9c0\ub3c4 \uc54a\uc544. ",
#    "text_b": null
#  },
#  {
#    "guid": "train-220",
#    "label": "80",
#    "text_a": "\uc65c \uc694\uc998 \ubb34\ub825\uac10\uc774 \ub4dc\ub294 \uac78\uae4c",
#    "text_b": null
#  },
#  {
#    "guid": "train-221",
#    "label": "10",
#    "text_a": "\ud558\ub8e8\ub3c4 \uace0\ub3c5\ud558\uc9c0 \uc54a\uc740 \ub0a0\uc774 \uc5c6\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-222",
#    "label": "90",
#    "text_a": "\uc0b4\uc774 \ube60\uc9c0\ub2c8\uae4c \uacc4\uc18d \uc6b0\uc6b8\ud574",
#    "text_b": null
#  },
#  {
#    "guid": "train-223",
#    "label": "70",
#    "text_a": "\ub5a1\ubcf6\uc774\ub97c \ubd10\ub3c4 \uba39\uace0 \uc2f6\ub2e4\ub294 \uc0dd\uac01\uc774 1\ub3c4 \uc548\ub4e4\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-224",
#    "label": "80",
#    "text_a": "\uc2a4\ud2b8\ub808\uc2a4 \ubc1b\uc544\uc11c \ubc25\ub9db\ub3c4 \uc5c6\uace0 \ub2e4 \uadc0\ucc2e\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-225",
#    "label": "10",
#    "text_a": "\ub0b4\uac00 \ub108\ubb34 \uc791\uc740 \uc0ac\ub78c\uac19\uc544\uc11c \uc0ac\ub294\uac8c \uad34\ub86d\uac8c \ub290\uaef4\uc838",
#    "text_b": null
#  },
#  {
#    "guid": "train-226",
#    "label": "10",
#    "text_a": "\uc778\uc0dd\uc774 \ubb34\ub108\uc838\ub0b4\ub9ac\uace0 \uc788\ub2e4\ub294 \uc0dd\uac01\uc774 \ub4e4\uc5c8\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-227",
#    "label": "70",
#    "text_a": "\uc790\uc2e0\uac10\uc774 \uc5c6\uc5b4\uc9c0\ub354\ub77c\uad6c\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-228",
#    "label": "70",
#    "text_a": "\uc26c\ub294 \uac83\ub3c4 \uc5c6\uc774 \ud1a0\ud558\uae30 \uc804\uae4c\uc9c0 \uba39\uc5b4\uc694",
#    "text_b": null
#  },
#  {
#    "guid": "train-229",
#    "label": "70",
#    "text_a": "\uc2a4\uce58\uae30\ub9cc \ud574\ub3c4 \ub0a0\uce74\ub85c\uc6cc\uc838",
#    "text_b": null
#  },
#  {
#    "guid": "train-230",
#    "label": "70",
#    "text_a": "\uba4d\ud574\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-231",
#    "label": "20",
#    "text_a": "\uc544\ubb34\ub798\ub3c4 \uc5b4\ub838\uc744 \ub54c \ud56d\uc0c1 \ud63c\uc790 \uc788\uc5b4\uc11c \uc774\ub807\uac8c \uc678\ub85c\uc6cc \ud558\ub294 \uac83 \uac19\uc544.",
#    "text_b": null
#  },
#  {
#    "guid": "train-232",
#    "label": "70",
#    "text_a": "\uadf8\ub54c\ubd80\ud130 \uba39\ub294 \uac78\ub85c \uc2a4\ud2b8\ub808\uc2a4\ub97c \ud480\uc5c8\ub358 \uac83 \uac19\uc544\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-233",
#    "label": "90",
#    "text_a": "\uc2e0\uacbd \uc4f8 \uac8c \uc65c \uc774\ub9ac \ub9ce\uc740\uc9c0 \uc624\ud788\ub824 \uc544\ubb34\uac83\ub3c4 \ubabb \ud558\uaca0\ub124",
#    "text_b": null
#  },
#  {
#    "guid": "train-234",
#    "label": "70",
#    "text_a": "\uc2dd\uc695\uc774 \ubc14\ub2e5\uc774\uc57c",
#    "text_b": null
#  },
#  {
#    "guid": "train-235",
#    "label": "10",
#    "text_a": "\uc0ac\ub78c\ub4e4 \uc18d\uc5d0 \uc788\uc5b4\ub3c4 \ub098 \ud63c\uc790 \uc788\ub294 \uac83 \uac19\uace0 \uc774 \ud5c8\ubb34\ud568\uacfc \uc11c\uae00\ud514\uc740 \uba54\uc6cc\uc9c0\uc9c0 \uc54a\ub294 \uac83 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-236",
#    "label": "80",
#    "text_a": "\uc9d1\uc5d0\uc11c\ub3c4 \ub098\uac00\uae30 \uc2eb\uace0 \uacf5\ubd80\ub3c4 \ud558\uae30 \uc2eb\uace0\u2026 \uc544\ubb34 \uac83\ub3c4 \ud558\uae30 \uc2eb\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-237",
#    "label": "70",
#    "text_a": "\ucd9c\uc0b0\uc77c \ub2e4\uac00\uc62c\uc218\ub85d \ub9c8\uc74c\ub3c4 \ucd08\uc870\ud558\uace0 \ubab8\uc774 \ubb34\uac70\uc6cc",
#    "text_b": null
#  },
#  {
#    "guid": "train-238",
#    "label": "5",
#    "text_a": "\uacc4\uc18d \uac00\uc871\ub4e4\uc774\ub791 \ub5a8\uc5b4\uc838 \uc788\uc5b4\uc11c \uc678\ub85c\uc6b4\ub370 \ub610 \ud55c\uad6d\uc5d0\uc11c \ub300\ud559 \ub2e4\ub2c8\uae34 \uc2eb\uac70\ub4e0\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-239",
#    "label": "20",
#    "text_a": "\ubd80\ubaa8\ub2d8\ub3c4 \uc65c \ubc8c\uc368 \uc544\uae30\ub97c \uac00\uc84c\ub0d0\uace0 \ucc28\uac11\uac8c \uc598\uae30\ud574",
#    "text_b": null
#  },
#  {
#    "guid": "train-240",
#    "label": "5",
#    "text_a": "\ubcd1\uc6d0\uc5d0\uc11c \ub9e4\uc77c \ub208\ub728\uace0 \uc7a0\ub4e4 \ub54c\ub9c8\ub2e4 \uc8fd\uace0 \uc2f6\uc5c8\uc5b4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-241",
#    "label": "90",
#    "text_a": "\ubc25 \uba39\uc744 \ub54c\ub9c8\ub2e4 \uc5b5\uc9c0\ub85c \uba39\uac8c \ub418\uace0 \ub9c8\uc74c\uc774 \ub2f5\ub2f5\ud574\uc694",
#    "text_b": null
#  },
#  {
#    "guid": "train-242",
#    "label": "70",
#    "text_a": "\uc77c\uc0c1\uc0dd\ud65c\uc774 \ud798\ub4e4 \uc815\ub3c4\ub85c \ud798\uc774 \uc790\uc8fc \ube60\uc9c0\ub294 \uac70 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-243",
#    "label": "10",
#    "text_a": "\uc81c\uc655 \ud574\uc57c \ud558\ub294 \uac8c \ubaa8\ub450 \ub0b4 \uc798\ubabb\uc778 \uac83 \uac19\uc544 ",
#    "text_b": null
#  },
#  {
#    "guid": "train-244",
#    "label": "70",
#    "text_a": "\ub0a8\ud3b8\ub54c\ubb38\uc5d0 \uc608\ubbfc\ud574",
#    "text_b": null
#  },
#  {
#    "guid": "train-245",
#    "label": "80",
#    "text_a": "\uc9d1\uc5d0 \uac00\uae30\ub3c4 \uc2eb\uace0, \ud63c\uc790 \uc788\uace0 \uc2f6\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-246",
#    "label": "5",
#    "text_a": "\uc798 \ub54c \ub418\uba74 \ub354 \ub2f5\ub2f5\ud574",
# ...
#    "text_b": null
#  },
#  {
#    "guid": "train-920",
#    "label": "10",
#    "text_a": "\uc660\uc9c0 \uc791\uc544\uc9c0\ub294 \uae30\ubd84\uc774 \ub4e4\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-921",
#    "label": "10",
#    "text_a": "\ubcf4\ud0dc\uc904\uac83\ub3c4 \uc544\ub2c8\uba74\uc11c \uc65c \ub2e4\ub4e4 \ub098\ud55c\ud14c \uc190\uac00\ub77d\uc9c8\uc744 \ud574\ub300\ub294\uac78\uae4c",
#    "text_b": null
#  },
#  {
#    "guid": "train-922",
#    "label": "70",
#    "text_a": "\uadfc\ub370 \ub3cc\uc544\uc624\ub294 \uae38\uc5d0 \uc815\ub9d0 \ub108\ubb34 \uc6b0\uc6b8\ud574\uc84c\uc5b4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-923",
#    "label": "10",
#    "text_a": "\uce5c\uad6c\ub4e4\uc774 \uc790\uafb8 \ub0b4\uac00 \ub9d0\ub9cc \ud558\uba74 \ube48\uc815\uac70\ub824\uc11c \uc57d\uc18d\uc744 \uc544\uc608 \uc548 \uc7a1\uac8c \ub3fc.",
#    "text_b": null
#  },
#  {
#    "guid": "train-924",
#    "label": "70",
#    "text_a": "\uc139\uc2a4 \uc0dd\uac01\uc774 \uc548 \ub4dc\ub2c8\uae4c \ub354 \ubd88\uc548\ud574\uc84c\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-925",
#    "label": "70",
#    "text_a": "\ub204\uac00 \uc704\uc5d0 \uc62c\ub77c\ud0c4 \uac83\ucc98\ub7fc \ubab8\uc774 \ubb34\uac81\uace0 \ud558\ub8e8 \uc885\uc77c \uc548\uc808\ubd80\uc808\ubabb\ud574",
#    "text_b": null
#  },
#  {
#    "guid": "train-926",
#    "label": "70",
#    "text_a": "\ucd5c\uadfc\uc5d0 \uc2dd\uc695\uc774 \ub9ce\uc774 \uc904\uc5c8\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-927",
#    "label": "5",
#    "text_a": "\uc0b6\uc774 \ud558\ucc2e\uac8c \ub290\uaef4\uc838\uc694",
#    "text_b": null
#  },
#  {
#    "guid": "train-928",
#    "label": "10",
#    "text_a": "\uc544\ube60\ub97c \uc5b4\ub838\uc744 \ub54c\ubd80\ud130 \ub108\ubb34 \ubbf8\uc6cc\ud574\uc11c \uadf8\ub7f0\uc9c0 \uc9c0\uae08\uc740 \uc544\ubb34\ub807\uc9c0 \uc54a\uc558\ub294\ub370.",
#    "text_b": null
#  },
#  {
#    "guid": "train-929",
#    "label": "70",
#    "text_a": "\ub178\ub825\uc73c\ub85c\ub3c4 \uc548 \ub418\ub294 \uc77c\uc774 \uc788\ub2e4\ub294\uac8c \ub108\ubb34 \ud798\ub4e4\uc5b4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-930",
#    "label": "10",
#    "text_a": "\uad00\uc2ec \uac00\ub294 \uac83\ub3c4 \uc5c6\uace0 \uadf8\ub0e5 \ud558\ub8e8 \uc885\uc77c \uc2ec\ub4dc\ub801\ud558\uac8c \ub204\uc6cc\uc788\ub294 \uac83 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-931",
#    "label": "20",
#    "text_a": "\uc544\ub4e4\uc774 \ubbf8\uc6cc",
#    "text_b": null
#  },
#  {
#    "guid": "train-932",
#    "label": "70",
#    "text_a": "\uc694\uc998 \uac10\uc815\uae30\ubcf5\uc774 \ub108\ubb34 \uc2ec\ud574\uc11c \uac11\uc790\uae30 \ud654\ub97c \ub0bc \ub54c\ub3c4 \ub9ce\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-933",
#    "label": "10",
#    "text_a": "\ubb34\uc2dc\ub2f9\ud558\ub294 \uae30\ubd84\uc774 \ub108\ubb34 \ud798\ub4e4\uc5c8\uc5b4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-934",
#    "label": "5",
#    "text_a": "\uc8c4\uc778\uc774 \ub41c \uac83 \uac19\uc740 \ub290\ub08c\uc5d0 \uc0ac\ub85c\uc7a1\ud600\uc11c \uc544\ubb34\uac83\ub3c4 \ubabb \ud558\uaca0\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-935",
#    "label": "70",
#    "text_a": "\ud558\ub098\ubd80\ud130 \uc5f4\uae4c\uc9c0 \ub2e4 \ub9c8\uc74c\uc5d0 \uc548 \ub4e4\uace0 \ub0b4 \uc2ec\uacbd\uc744 \uac74\ub4dc\ub9b4 \uc218\uac00 \uc788\uc744\uae4c",
#    "text_b": null
#  },
#  {
#    "guid": "train-936",
#    "label": "5",
#    "text_a": "\ubc14\ub78c \ud540 \ub0a8\ud3b8\uc744 \ubcf4\uace0 \uc788\uc73c\uba74 \uadf8\ub0e5 \uc808\ub9dd\uac10\uc774 \ubc00\ub824\uc624\uace0 \ub108\ubb34 \uace0\ud1b5\uc2a4\ub7ec\uc6cc",
#    "text_b": null
#  },
#  {
#    "guid": "train-937",
#    "label": "10",
#    "text_a": "\uc0ac\ub294 \uac8c \ube44\ucc38\ud574\uc84c\uc5b4\uc694",
#    "text_b": null
#  },
#  {
#    "guid": "train-938",
#    "label": "90",
#    "text_a": "\uc7a0\ub4dc\ub294 \uac8c \uc9c4\uc9dc \ud798\ub4e4\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-939",
#    "label": "20",
#    "text_a": "\uc791\uc740 \uc18c\ub9ac\uc5d0\ub3c4 \uae5c\uc9dd\uae5c\uc9dd \ub180\ub77c\uace0\u2026\ub0b4\uac00 \ub108\ubb34 \ucd08\ub77c\ud574.",
#    "text_b": null
#  },
#  {
#    "guid": "train-940",
#    "label": "70",
#    "text_a": "\ub204\uac00 \ub0b4 \ubc25\ub9db\uc744 \ub69d \ub5a8\uc5b4\ud2b8\ub9b0 \uac83 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-941",
#    "label": "10",
#    "text_a": "\ub0b4\uac00 \ud558\ucc2e\uc544 \ubcf4\uc5ec",
#    "text_b": null
#  },
#  {
#    "guid": "train-942",
#    "label": "10",
#    "text_a": "\ub2e4 \ud5c8\ubb34\ud574\uc9c0\ub124\uc694",
#    "text_b": null
#  },
#  {
#    "guid": "train-943",
#    "label": "20",
#    "text_a": "\uc0b4\uc774 \ub108\ubb34 \ub9ce\uc774 \uca84\uc11c \uc81c \uc790\uc2e0\uc774 \ubcf4\uc798\uac83 \uc5c6\uc774 \ub290\uaef4\uc838\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-944",
#    "label": "10",
#    "text_a": "\uc784\uc2e0\ud558\uace0 \ub098 \uc790\uc2e0\uc5d0 \ub300\ud55c \ud655\uc2e0\uac19\uc740\uac8c \uc5c6\uc5b4\uc838\uc11c \uc0c1\uc2ec\uc774 \ucee4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-945",
#    "label": "5",
#    "text_a": "\uadf8\ub798\uc11c \uc2eb\ub2e4 \ud558\uace0 \ub9c9 \ud654\ub0b4\uace0 \ub098\uc654\ub294\ub370 \uadf8 \ud6c4\ub85c \ub108\ubb34 \ucc29\uc7a1\ud558\ub2e4\u2026",
#    "text_b": null
#  },
#  {
#    "guid": "train-946",
#    "label": "70",
#    "text_a": "\uc9c1\ud6c4\uc5d0\ub294 \uc815\ub9d0 \ub9e4\uc77c \uc6b0\uc6b8\ud588\ub358 \uac83 \uac19\uc544\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-947",
#    "label": "5",
#    "text_a": "\uc678\ub85c\uc6cc\uc11c \uc0ac\ub294 \uac8c \uc758\ubbf8 \uc5c6\ub2e4\uace0 \uc0dd\uac01\ud558\ub294\uc9c0\ub3c4 \ubab0\ub77c",
#    "text_b": null
#  },
#  {
#    "guid": "train-948",
#    "label": "20",
#    "text_a": "\uc81c\uac00 \uc815\ub9d0 \ubabb\ub09c \uc5c4\ub9c8 \uac19\uace0\u2026 \ub0a8\ub4e4 \ub2e4 \ud558\ub294\ub370 \ub098\ub294 \uc65c \ubabb \ud558\ub294 \uac74\uc9c0 \ud55c\uc2ec\ud558\uace0\u2026",
#    "text_b": null
#  },
#  {
#    "guid": "train-949",
#    "label": "10",
#    "text_a": "\uc694\uc998 \uc0ac\ub294 \uac8c \ube44\ucc38\ud558\ub2e4",
#    "text_b": null
#  },
#  {
#    "guid": "train-950",
#    "label": "10",
#    "text_a": "\ud765\ubbf8\uac00 \uc790\uafb8 \ub69d\ub69d \ub5a8\uc5b4\uc9c0\ub294 \uac83 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-951",
#    "label": "70",
#    "text_a": "\uc27d\uac8c \ubab8\uc774 \ub178\uace4\ud574\uc9c0\uace0 \uc218\uba74\ub7c9\uc774 \ub9ce\uc544\uc84c\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-952",
#    "label": "80",
#    "text_a": "\uc9c4\uc9dc \uadf8\ub7ec\uba74 \ub098 \uc5b4\ub5a1\ud558\uc9c0?",
#    "text_b": null
#  },
#  {
#    "guid": "train-953",
#    "label": "70",
#    "text_a": "\ucd08\uc870\ud558\uace0 \ubab8\uc774 \ud53c\ub85c\ud574\uc11c \uc549\uc544 \uc788\uc9c0\ub3c4 \ubabb\ud558\uaca0\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-954",
#    "label": "70",
#    "text_a": "\ubab8\uc774 \ub108\ubb34 \ud53c\uace4\ud558\uace0 \ubb34\uac70\uc6cc\uc11c \uc0ac\uc18c\ud55c \uc77c\uc5d0\ub3c4 \uc9d1\uc911\uc774 \uc548 \ub3fc",
#    "text_b": null
#  },
#  {
#    "guid": "train-955",
#    "label": "70",
#    "text_a": "\ubcd1\uc6d0\uc5d0\uc11c \ub300\uae30\ud558\uace0 \uc788\uc744 \ub54c\uac00 \uc81c\uc77c \uc870\ub9c8\uc870\ub9c8\ud558\uace0 \uc228 \ucc28",
#    "text_b": null
#  },
#  {
#    "guid": "train-956",
#    "label": "10",
#    "text_a": "\ubab8 \uc0c1\ud0dc\uac00 \ub108\ubb34 \uc548 \uc88b\uc544\uc11c \uc790\uc0b4\ud558\uace0 \uc2f6\ub2e4",
#    "text_b": null
#  },
#  {
#    "guid": "train-957",
#    "label": "80",
#    "text_a": "\ud690\uba38\ub9ac \ud55c \uac00\ub2e5\uc774 \ub108\ubb34 \uc120\uba85\ud558\uba74 \uc138\uc0c1 \uc6b0\uc6b8\ud574\uc9c4\ub2e4\ub2c8\uae4c.",
#    "text_b": null
#  },
#  {
#    "guid": "train-958",
#    "label": "70",
#    "text_a": "\uc6c0\uc9c1\uc774\uae30\uac00 \uadc0\ucc2e\uc544\uc11c.",
#    "text_b": null
#  },
#  {
#    "guid": "train-959",
#    "label": "20",
#    "text_a": "\uce5c\uad6c \uc5bc\uad74 \ubcf4\uae30\uac00 \uc5b4\ub824\uc6cc\uc838\uc11c \ub9c8\uc74c\uc774 \uc801\uc801\ud574",
#    "text_b": null
#  },
#  {
#    "guid": "train-960",
#    "label": "10",
#    "text_a": "\uc138\uc0c1\uc5d0 \ub098\ub9cc\ud07c \ubcd1\uc2e0\uac19\uc774 \uc0dd\uae34 \uc0ac\ub78c\uc740 \uc5c6\ub2e4\ub294 \uc0dd\uac01\uc774 \ub4e4 \uc815\ub3c4\uc57c.",
#    "text_b": null
#  },
#  {
#    "guid": "train-961",
#    "label": "80",
#    "text_a": "\uc5b4\ub5bb\uac8c \uc774\ub807\uac8c \uc544\ubb34 \ud798\uc774 \uc548 \ub098\uc9c0?",
#    "text_b": null
#  },
#  {
#    "guid": "train-962",
#    "label": "10",
#    "text_a": "\ub108\ubb34 \ud798\ub4e4\uc5b4\uc11c \uc790\uc0b4 \uc2dc\ub3c4\ub3c4 \ud588\uc5c8\uc5b4\uc694...",
#    "text_b": null
#  },
#  {
#    "guid": "train-963",
#    "label": "90",
#    "text_a": "\uc9d1\uc5d0\uc11c \uc0b4\ub9bc\ub9cc \ud558\ub824\ub2c8 \uc2ac\ub7fc\ud504\uac00 \ucc3e\uc544\uc654\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-964",
#    "label": "5",
#    "text_a": "\ub0b4\uac00 \ubb54\uac00 \uc911\uc694\ud55c \uac78 \uc783\uc5b4\ubc84\ub9b0 \uac70 \uac19\uace0 \uc2e4\ud328\ud588\ub2e4\ub294 \uc0dd\uac01\uc774 \ub4e4\uc5b4\uc694",
#    "text_b": null
#  },
#  {
#    "guid": "train-965",
#    "label": "70",
#    "text_a": "\ubb34\uc2a8 \uc77c\uc774 \uc788\uc5c8\ub358 \uac74 \uc544\ub2cc\ub370 \uc548\uc808\ubd80\uc808\ubabb\ud558\uace0 \uc544\ubb34\uac83\ub3c4 \ud558\uae30 \uc2eb\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-966",
#    "label": "70",
#    "text_a": "\uccb4\uc911\uc774 \uc904\uc5b4\uc11c \uc624\ud788\ub824 \uacc4\uc18d \uba39\uc5b4\uc694",
#    "text_b": null
#  },
#  {
#    "guid": "train-967",
#    "label": "90",
#    "text_a": "\uc0b4 \uae38\uc774 \uc554\ub2f4\ud558\ub2c8\uae4c \uc544\uae30\uc5d0 \ub300\ud55c \uc560\uc815\ub3c4 \uc548 \uc0dd\uaca8",
#    "text_b": null
#  },
#  {
#    "guid": "train-968",
#    "label": "20",
#    "text_a": "\uadf8\ub0e5 \ub2e4 \ub54c\ub824 \uce58\uace0 \uc2f6\uace0 \ub0a8\ud3b8 \uc6d0\ub9dd\ub9cc \ub298\uc5b4\uac00\ub294 \uac83 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-969",
#    "label": "70",
#    "text_a": "\ub0a8\ud3b8\ub9cc \ubcf4\uba74 \uc18d\uc0c1\ud55c \uae30\ubd84\uc774 \ub4e4\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-970",
#    "label": "70",
#    "text_a": "\ubab8\uc774 \ud798\ub4dc\ub2c8\uae4c \uc139\uc2a4\ud558\uace0 \uc2f6\uc740 \uc695\uad6c\ub3c4 \uc0ac\ub77c\uc838",
#    "text_b": null
#  },
#  {
#    "guid": "train-971",
#    "label": "70",
#    "text_a": "\ubc30\uac00 \ub098\uc628 \ub0b4\ubaa8\uc2b5\uc774 \uc2eb\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-972",
#    "label": "5",
#    "text_a": "\uc5bc\ub9c8\ub098 \ud5c8\ud0c8\ud558\uace0 \ud654\uac00 \ub098\ub358\uc9c0 \uac00\ub9cc\ud788 \uc788\uc744 \uc218\uac00 \uc5c6\uc5c8\uc5b4\uc694",
#    "text_b": null
#  },
#  {
#    "guid": "train-973",
#    "label": "80",
#    "text_a": "\ubb54\uac00\ub97c \uc539\uace0 \uc0bc\ud0a4\ub294 \uac83\ub3c4 \uadc0\ucc2e\uc544\uc11c \uc544\uc608 \uc548 \uba39\uc5c8\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-974",
#    "label": "70",
#    "text_a": "\uc11c\ub7ec\uc6b4 \uac10\uc815 \ub54c\ubb38\uc5d0 \ud798\ub4e4\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-975",
#    "label": "10",
#    "text_a": "\ucd9c\uc0b0\uc774 \uc5bc\ub9c8 \uc548 \ub0a8\uc73c\ub2c8\uae4c \uc9c4\uc9dc \uac10\uc815\uc8fc\uccb4\uac00 \uc548\ub418\uace0 \uadf8\ub0e5 \ubd84\ud574\uc694",
#    "text_b": null
#  },
#  {
#    "guid": "train-976",
#    "label": "90",
#    "text_a": "\ud55c\ub3d9\uc548 \uc548 \uba39\uc73c\uba74 \uc5b4\ub290 \ub0a0\uc740 \ud3ed\uc2dd\ud574.",
#    "text_b": null
#  },
#  {
#    "guid": "train-977",
#    "label": "10",
#    "text_a": "\uc790\uafb8 \ubbf8\uc6cc\uc9c0\ub294 \uac78\uae4c",
#    "text_b": null
#  },
#  {
#    "guid": "train-978",
#    "label": "80",
#    "text_a": "\uadfc\ub370 \uc694\uc998\uc740 \uc544\uc774 \ub54c\ubb38\uc5d0 \ub108\ubb34 \ud798\ub4e4\ub2e4\ub294 \uc0dd\uac01\uc774 \ub4e4\uc5b4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-979",
#    "label": "10",
#    "text_a": "\uc0ac\ub791\uc744 \ubabb \ubc1b\ub294 \uac83 \uac19\uc544\uc11c \ub0b4\uac00 \ud558\ucc2e\uac8c \ub290\uaef4\uc838.",
#    "text_b": null
#  },
#  {
#    "guid": "train-980",
#    "label": "10",
#    "text_a": "\uc774\uc820 \uadf8\ub0e5 \ubaa8\ub4e0 \uac8c \ucc98\ucc38\ud55c \uac83 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-981",
#    "label": "70",
#    "text_a": "\uc815\ub9d0 \ub9e4\uc77c \ub9e4\uc77c \uac00\uc2b4\uc774 \ucc22\uc5b4\uc9c0\ub294 \uac83 \uac19\uc544.",
#    "text_b": null
#  },
#  {
#    "guid": "train-982",
#    "label": "10",
#    "text_a": "\ub098 \ub108\ubb34 \ub9c8\uc74c\uc774 \uacf5\ud5c8\ud574",
#    "text_b": null
#  },
#  {
#    "guid": "train-983",
#    "label": "5",
#    "text_a": "\ub178\uc0b0 \uc774\ub77c \uc5b4\ub835\uac8c \uac00\uc9c4 \uc544\uc778\ub370 \uc548 \uc88b\ub2e4\uace0 \ud558\ub2c8\uae4c \ub108\ubb34 \ud5c8\ub9dd\ud574",
#    "text_b": null
#  },
#  {
#    "guid": "train-984",
#    "label": "10",
#    "text_a": "\ub0a8\ud3b8\uc774 \ubd84\uc720\uac12\ub3c4 \ubabb \ubc8c\uc5b4\uc624\ub2c8\uae4c \ub108\ubb34 \ub2f5\ub2f5\ud558\uace0 \ub0b4 \uc778\uc0dd\uc774 \ud55c\uc2ec\ud558\uac8c \ub290\uaef4\uc84c\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-985",
#    "label": "20",
#    "text_a": "\uc778\uc0dd \uc811\uace0 \uc2f6\uc5b4\uc694",
#    "text_b": null
#  },
#  {
#    "guid": "train-986",
#    "label": "90",
#    "text_a": " \uadf8\ub798\uc11c \uadf8\ub0e5 \uc774\uc464\uc2dc\uac1c\ub9cc \ubd10\ub3c4 \uc774\uc820 \uae30\ubd84\uc774 \ub9c9 \ub098\ube60\uc838.",
#    "text_b": null
#  },
#  {
#    "guid": "train-987",
#    "label": "90",
#    "text_a": "\uaca8\uc6b8\uc774\uba74 \uba39\ub294 \uc591\uc774 \ub354 \uc904\uc5b4\ub4dc\ub294 \uac83 \uac19\uc544",
#    "text_b": null
#  },
#  {
#    "guid": "train-988",
#    "label": "5",
#    "text_a": "\uc6b0\uc6b8\ud574\uc11c \uadf8\ub7f0\uac00 \uc7ac\ubbf8\uc788\ub294 \uac8c \uc5c6\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-989",
#    "label": "70",
#    "text_a": "\uc6b0\uc6b8\ud55c\ub370\u2026 \ub610 \ud55c\ud3b8\uc73c\ub85c\ub294 \uadf8\ub798 \uc774\ub7ec\ub2e4 \uc8fd\uc73c\uba74 \uadf8\ub9cc\uc774\uc9c0 \uc774\ub7f0 \uc0dd\uac01\ub3c4 \ub4e4\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-990",
#    "label": "70",
#    "text_a": "\uc2dc\uc5b4\uba38\ub2c8\ub9cc \ubcf4\uba74 \ub2f5\ub2f5\ud558\uace0 \ubc25 \uc0dd\uac01\ub3c4 \uc548 \ub098",
#    "text_b": null
#  },
#  {
#    "guid": "train-991",
#    "label": "70",
#    "text_a": "\ubcd1\uc6d0\uc5d0\ub9cc \uc788\uc73c\ub2c8\uae4c \uc624\ud788\ub824 \ub354 \ubabb \uc790\ub294 \uac83 \uac19\uc544\uc694",
#    "text_b": null
#  },
#  {
#    "guid": "train-992",
#    "label": "10",
#    "text_a": "\uce5c\uad6c\ub4e4\uc774 \uad1c\ucc2e\ub2e4\uace0 \ud558\ub294\ub370\ub3c4 \ub0b4\uac00 \ub108\ubb34 \uc6d0\ub9dd\uc2a4\ub7fd\ub2e4",
#    "text_b": null
#  },
#  {
#    "guid": "train-993",
#    "label": "20",
#    "text_a": "\ub098 \ud63c\uc790\ub9cc \ub4a4\uc9d1\uc5b4 \uc37c\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-994",
#    "label": "5",
#    "text_a": "\ub0b4\uac00 \uc774\ub7f0 \uac83\ub3c4 \ub2e4 \ub0a8\ud3b8 \ub54c\ubb38\uc774\ub2e4 \uc774\ub7f0 \uc0dd\uac01\uc774 \ub4e4\uc5b4\uc11c \ubbf8\uc6b4 \uac70\uc608\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-995",
#    "label": "10",
#    "text_a": "\uc5bc\uad74\uc5d0 \ub300\ud55c \uc790\uc2e0\uac10\uc774 \uc5c6\uc5b4\uc11c \uc0ac\uc9c4\uc744 \ucc0d\uae30 \uc2eb\uc5b4.",
#    "text_b": null
#  },
#  {
#    "guid": "train-996",
#    "label": "90",
#    "text_a": "\uc5ec\ud589 \uc900\ube44\ud558\ub294\ub370 \uc2ac\ub7fc\ud504\uac00 \uc654\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-997",
#    "label": "70",
#    "text_a": "\ubab8\uc5d0 \uae30\uc6b4\uc774 \ud558\ub098\ub3c4 \uc5c6\uace0 \ucd95 \ucc98\uc838\uc11c \uc544\ubb34\uac83\ub3c4 \ubabb \ud558\uaca0\uc5b4",
#    "text_b": null
#  },
#  {
#    "guid": "train-998",
#    "label": "10",
#    "text_a": "\uc81c\uac00 \uc5b4\uca4c\ub2e4 \uc774\ub534 \uc0ac\ub78c\uc774 \ub41c \uac74\uc9c0 \ubaa8\ub974\uaca0\uc5b4\uc694.",
#    "text_b": null
#  },
#  {
#    "guid": "train-999",
#    "label": "70",
#    "text_a": "\uadfc\ub370 \ub450 \ub2ec\ucbe4 \uc9c0\ub098\ub2c8\uae4c \uadf8 \ub54c\ubd80\ud130 \uae09\uaca9\ud558\uac8c \uc6b0\uc6b8\ud574\uc84c\uc5b4.",
#    "text_b": null
#  },
#  ...]

# %%
args.model_name_or_path
# Out:
# 'monologg/koelectra-base-discriminator'

# %%
config = CONFIG_CLASSES[args.model_type].from_pretrained(   
        args.model_name_or_path
)

# config2

# %%
config
# Out:
# ElectraConfig {
#   "architectures": [
#     "ElectraForPreTraining"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "embedding_size": 768,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "electra",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "summary_activation": "gelu",
#   "summary_last_dropout": 0.1,
#   "summary_type": "first",
#   "summary_use_proj": true,
#   "transformers_version": "4.21.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 32200
# }

# %%
tokenizer = TOKENIZER_CLASSES[args.model_type].from_pretrained(   # model_type: koelectra-base, ElectraTokenizer 
    args.model_name_or_path,
    do_lower_case = args.do_lower_case,
)

model = MODEL_FOR_REGRESSION[args.model_type].from_pretrained(
    args.model_name_or_path,
    config=config
)
# Out:
# Some weights of the model checkpoint at monologg/koelectra-base-discriminator were not used when initializing ElectraModel: ['discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense.bias', 'discriminator_predictions.dense.weight', 'discriminator_predictions.dense_prediction.weight']
# - This IS expected if you are initializing ElectraModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
model
# Out:
# ElectraModel(
#   (embeddings): ElectraEmbeddings(
#     (word_embeddings): Embedding(32200, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): ElectraEncoder(
#     (layer): ModuleList(
#       (0): ElectraLayer(
#         (attention): ElectraAttention(
#           (self): ElectraSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): ElectraSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): ElectraIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): ElectraOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): ElectraLayer(
#         (attention): ElectraAttention(
#           (self): ElectraSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): ElectraSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): ElectraIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): ElectraOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): ElectraLayer(
#         (attention): ElectraAttention(
#           (self): ElectraSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): ElectraSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): ElectraIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): ElectraOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (3): ElectraLayer(
#         (attention): ElectraAttention(
#           (self): ElectraSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): ElectraSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): ElectraIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): ElectraOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (4): ElectraLayer(
#         (attention): ElectraAttention(
#           (self): ElectraSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): ElectraSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): ElectraIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): ElectraOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (5): ElectraLayer(
#         (attention): ElectraAttention(
#           (self): ElectraSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): ElectraSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): ElectraIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): ElectraOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (6): ElectraLayer(
#         (attention): ElectraAttention(
#           (self): ElectraSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): ElectraSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): ElectraIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): ElectraOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (7): ElectraLayer(
#         (attention): ElectraAttention(
#           (self): ElectraSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): ElectraSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): ElectraIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): ElectraOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (8): ElectraLayer(
#         (attention): ElectraAttention(
#           (self): ElectraSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): ElectraSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): ElectraIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): ElectraOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (9): ElectraLayer(
#         (attention): ElectraAttention(
#           (self): ElectraSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): ElectraSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): ElectraIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): ElectraOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (10): ElectraLayer(
#         (attention): ElectraAttention(
#           (self): ElectraSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): ElectraSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): ElectraIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): ElectraOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (11): ElectraLayer(
#         (attention): ElectraAttention(
#           (self): ElectraSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): ElectraSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): ElectraIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): ElectraOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
# )

# %%
class ElectraRegressor(nn.Module):
    def __init__(self, electra, config):
        # 부모 생성자 초기화 
        # super().__init__(config) 시 오류 발생 
        super(ElectraRegressor, self).__init__() 
        self.electra = electra
        self.cls_layer = nn.Linear(config.hidden_size, 128)
        self.regressor = nn.Sequential(nn.Dropout(0.1), nn.Linear(128, 1))
        # self.relu1 = nn.ReLU()
        # self.fc1 = nn.Linear(128, 128)
        # self.tanh = nn.Tanh()
        # self.fc2 = nn.Linear(128, 1)
    
    def forward(self, input_ids, attention_mask, token_type_ids):
        outputs = self.electra(input_ids=input_ids,
                               attention_mask=attention_mask,
                               token_type_ids=token_type_ids)
        logits = outputs.last_hidden_state[:, 0, :]
        # print(f'logits: {len(logits)}')
        output = self.cls_layer(logits)
        output = self.regressor(output)
        # output = self.fc1(output)
        # output = self.tanh(output)
        # output = self.fc2(output)
        return output

# %%
args.device = "cuda" if torch.cuda.is_available() and not args.no_cuda else "cpu"
electra_model = ElectraRegressor(model, config=config).to(args.device)

# %%
electra_model
# Out:
# ElectraRegressor(
#   (electra): ElectraModel(
#     (embeddings): ElectraEmbeddings(
#       (word_embeddings): Embedding(32200, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): ElectraEncoder(
#       (layer): ModuleList(
#         (0): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (cls_layer): Linear(in_features=768, out_features=128, bias=True)
#   (regressor): Sequential(
#     (0): Dropout(p=0.1, inplace=False)
#     (1): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
def train(args, model, train_dataset, val_dataset=None, test_dataset=None):
    train_sampler = RandomSampler(train_dataset)
    train_dataloader = DataLoader(train_dataset, sampler=train_sampler, batch_size=args.train_batch_size)
    eval_sampler = SequentialSampler(val_dataset)
    eval_dataloader = DataLoader(val_dataset, sampler=eval_sampler, batch_size=args.eval_batch_size)

    global_step = 0
    nb_eval_steps = 0
    train_mse = []
    eval_mse = [] 
    t_total = len(train_dataloader) // args.gradient_accumulation_steps * args.num_train_epochs

    # Prepare optimizer and schedule (linear warmup and decay)
    no_decay = ['bias', 'LayerNorm.weight']
    optimizer_grouped_parameters = [
        {'params': [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)],
         'weight_decay': args.weight_decay},
        {'params': [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)], 'weight_decay': 0.0}
    ]
    optimizer = AdamW(optimizer_grouped_parameters, lr=args.learning_rate, eps=args.adam_epsilon)
    scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=int(t_total * args.warmup_proportion), num_training_steps=t_total)

    model.zero_grad()
    for epoch in range(int(args.num_train_epochs)):
        tr_loss = 0.0
        eval_loss = 0.0
        model.train()
        # epoch_iterator = progress_bar(train_dataloader, parent=mb)
        for step, batch in enumerate(train_dataloader):
            optimizer.zero_grad()
            batch = tuple(t.to(args.device) for t in batch)
            inputs = {
                "input_ids": batch[0],
                "attention_mask": batch[1],
                "token_type_ids": batch[2],
                # "labels": batch[3]
            }
            # print(batch[3])
            outputs = model(**inputs)
            #print(np.shape(outputs.squeeze()))
            #print(f'input_ids: {len(batch[0][0])}, attention_mask: {len(batch[1][0])}, \
            #token_type_ids: {len(batch[2][0])}')
            #print('-'*20)
            #print(f'input_ids: {len(batch[0])}, attention_mask: {len(batch[1])}, \
            #token_type_ids: {len(batch[2])}, labels: {len(batch[3])}')
            #print('-')
            #print(f'input_ids: {batch[0][0]}, attention_mask: {batch[1][0]}, token_type_ids: {batch[2][0]}, labels: {batch[3]}')
            criterion = nn.MSELoss()  # criterion = nn.MSELoss()
            loss = criterion(outputs.squeeze(), batch[3].type_as(outputs))
            print(f'outputs: {outputs.squeeze(), batch[3].type_as(outputs)}')
            # output = loss(batch[3], outputs[1])
            # output.backward()
            loss.backward()
            tr_loss += loss.item()
            torch.nn.utils.clip_grad_norm_(model.parameters(), args.max_grad_norm)
            optimizer.step() 
            scheduler.step()
            
        # mb.write("Epoch {} done".format(epoch + 1))
        print(f'Epoch {epoch + 1} done, tr_loss: {tr_loss / len(train_dataloader)}')
        train_mse.append(tr_loss / len(train_dataloader))
        
        for batch in eval_dataloader:
            model.eval()
            batch = tuple(t.to(args.device) for t in batch)

            with torch.no_grad():
                inputs = {
                    "input_ids": batch[0],
                    "attention_mask": batch[1],
                    "token_type_ids": batch[2],
                    # "labels": batch[3]
                }
                outputs = model(**inputs)
                tmp_eval_loss = criterion(outputs.squeeze(), batch[3].type_as(outputs))
                eval_loss += tmp_eval_loss.mean().item()

            nb_eval_steps += 1
        eval_loss = eval_loss / nb_eval_steps
        eval_mse.append(eval_loss)
    return train_mse, eval_mse

# %%
def evaluate(args, model, eval_dataset, mode, global_step=None):
    results = {}
    eval_sampler = SequentialSampler(eval_dataset)
    eval_dataloader = DataLoader(eval_dataset, sampler=eval_sampler, batch_size=args.eval_batch_size)

    eval_loss = 0.0
    nb_eval_steps = 0
    preds = None
    out_label_ids = None

    for batch in eval_dataloader:
        model.eval()
        batch = tuple(t.to(args.device) for t in batch)

        with torch.no_grad():
            inputs = {
                "input_ids": batch[0],
                "attention_mask": batch[1],
                "labels": batch[3]
            }
            if args.model_type not in ["distilkobert", "xlm-roberta"]:
                inputs["token_type_ids"] = batch[2]  # Distilkobert, XLM-Roberta don't use segment_ids
            outputs = model(**inputs)
            tmp_eval_loss, logits = outputs[:2]
            print(f'outputs: {outputs}')
            eval_loss += tmp_eval_loss.mean().item()
        nb_eval_steps += 1
        if preds is None:
            preds = logits.detach().cpu().numpy()
            out_label_ids = inputs["labels"].detach().cpu().numpy()
        else:
            preds = np.append(preds, logits.detach().cpu().numpy(), axis=0)
            out_label_ids = np.append(out_label_ids, inputs["labels"].detach().cpu().numpy(), axis=0)

    eval_loss = eval_loss / nb_eval_steps
    preds = np.argmax(preds, axis=1)
    return

# %%
train_dataset = load_and_cache_examples(args, tokenizer, mode="train") if args.train_file else None
dev_dataset = load_and_cache_examples(args, tokenizer, mode="dev") if args.dev_file else None
test_dataset = load_and_cache_examples(args, tokenizer, mode="test") if args.test_file else None

if dev_dataset == None:
    args.evaluate_test_during_training = True  # If there is no dev dataset, only use testset

if args.do_train:
    train_loss3, eval_loss3 = train(args, electra_model, train_dataset, dev_dataset, test_dataset)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_8418/2049112816.py in <module>
# ----> 1 train_dataset = load_and_cache_examples(args, tokenizer, mode="train") if args.train_file else None
#       2 dev_dataset = load_and_cache_examples(args, tokenizer, mode="dev") if args.dev_file else None
#       3 test_dataset = load_and_cache_examples(args, tokenizer, mode="test") if args.test_file else None
#       4
#       5 if dev_dataset == None:
#
# ~/chatbot/code/processor/wellness.py in seq_reg_load_and_cache_examples(args, tokenizer, mode)
#     187             mode: train, dev, test
#     188         """
# --> 189         file_to_read = None
#     190         if mode == "train":
#     191             file_to_read = self.args.train_file
#
# ~/chatbot/code/processor/wellness.py in seq_cls_convert_examples_to_features(args, examples, tokenizer, max_length, task)
#      82         return label_map[example.label]
#      83
# ---> 84     labels = [label_from_example(example) for example in examples]
#      85     batch_encoding = tokenizer.batch_encode_plus(
#      86         [(example.text_a, example.text_b) for example in examples],
#
# ~/chatbot/code/processor/wellness.py in <listcomp>(.0)
#      82         return label_map[example.label]
#      83
# ---> 84     labels = [label_from_example(example) for example in examples]
#      85     batch_encoding = tokenizer.batch_encode_plus(
#      86         [(example.text_a, example.text_b) for example in examples],
#
# ~/chatbot/code/processor/wellness.py in label_from_example(example)
#      80
#      81     def label_from_example(example):
# ---> 82         return label_map[example.label]
#      83
#      84     labels = [label_from_example(example) for example in examples]
#
# KeyError: '70'

# %%
torch.cuda.empty_cache()

# %% [markdown]
# #### 학습 모델 저장 (label_0, 1, 2에 대해 총 3개 모델 저장)

# %%
model_path = '/home/ubuntu/chatbot/code/model/'
model_name = 'KoELECTRA_label2_50.pt'

# %%
torch.save(electra_model.state_dict(), os.path.join(model_path, model_name))

# %%
len(train_loss), len(eval_loss)
# Out:
# (50, 50)

# %%
len(train_loss2), len(eval_loss2)
# Out:
# (50, 50)

# %%
len(train_loss3), len(eval_loss3)
# Out:
# (50, 50)

# %%
train_loss[:5], train_loss2[:5]
# Out:
# ([772.8231004185501,
#   611.5520064950388,
#   490.43624798828944,
#   488.2821599265006,
#   434.8644574780927],
#  [1096.9064809741783,
#   778.4333566518931,
#   557.9103478779363,
#   523.3704314088343,
#   576.8520503857462])

# %%
import matplotlib.pyplot as plt 

epochs_50 = list(range(0, 50))
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(list(range(len(train_loss))), train_loss, label='train_mse')
plt.plot(list(range(len(eval_loss))), eval_loss, label='test_mse')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt 

epochs_50 = list(range(0, 50))
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(list(range(len(train_loss2))), train_loss2, label='train_mse')
plt.plot(list(range(len(eval_loss2))), eval_loss2, label='test_mse')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt 

epochs_50 = list(range(0, 50))
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(list(range(len(train_loss3))), train_loss3, label='train_mse')
plt.plot(list(range(len(eval_loss3))), eval_loss3, label='test_mse')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt 

epochs_50 = list(range(0, 50))
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)

plt.plot(list(range(len(train_loss))), train_loss, label='label_0_train_mse')
plt.plot(list(range(len(eval_loss))), eval_loss, label='label_0_val_mse')
plt.plot(list(range(len(train_loss2))), train_loss2, label='label_1_train_mse')
plt.plot(list(range(len(eval_loss2))), eval_loss2, label='label_1_val_mse')
plt.plot(list(range(len(train_loss3))), train_loss3, label='label_2_train_mse')
plt.plot(list(range(len(eval_loss3))), eval_loss3, label='label_2_val_mse')

plt.legend()
plt.show()

# %%
train_loss
# Out:
# [772.8231004185501,
#  611.5520064950388,
#  490.43624798828944,
#  488.2821599265006,
#  434.8644574780927,
#  413.2517222465081,
#  345.30871746611837,
#  291.84705646221454,
#  273.2715909760134,
#  236.26399146115102,
#  206.0097859998212,
#  182.68990837530947,
#  178.9109993108539,
#  173.31270002920093,
#  172.68905768506104,
#  162.09778359582194,
#  181.86584856039704,
#  161.31238839777816,
#  158.1131588352165,
#  144.59443213548948,
#  149.09711532210028,
#  135.34380668461523,
#  128.6349981556768,
#  125.79945226178121,
#  118.37369502268507,
#  105.3681675072099,
#  98.30302238464355,
#  92.4668271629308,
#  89.02329974987833,
#  78.17587971767055,
#  72.50718496954163,
#  70.77371084411008,
#  72.41921055516272,
#  67.11192991901002,
#  59.02904622929551,
#  62.53417204534728,
#  53.90817877281469,
#  53.270173758567374,
#  50.45254550091798,
#  46.57645243226884,
#  43.448093838516286,
#  39.967972701209845,
#  39.488960822689094,
#  36.14842893606843,
#  35.28290027439794,
#  35.13329621860415,
#  33.41239726663034,
#  34.415997481266395,
#  35.22298966761816,
#  31.226297700684206]

# %%
import matplotlib.pyplot as plt 

f, ax = plt.subplots(1, 3, figsize=(16, 6))
epochs_50 = list(range(0, 50))
idx = 0 

ax[0].plot(epochs_50, train_loss, color='blue', label='Train MSE')
ax[0].plot(epochs_50, eval_loss, color='orange', label='Val MSE')
ax[0].set_xlabel(f'label 0', fontweight='bold')
ax[0].legend()

ax[1].plot(epochs_50, train_loss2, color='blue', label='Train MSE')
ax[1].plot(epochs_50, eval_loss2, color='orange', label='Val MSE')
ax[1].set_xlabel(f'label 1', fontweight='bold')
ax[1].legend()

ax[2].plot(epochs_50, train_loss3, color='blue', label='Train MSE')
ax[2].plot(epochs_50, eval_loss3, color='orange', label='Val MSE')
ax[2].set_xlabel(f'label 2', fontweight='bold')
ax[2].legend()

plt.show()

# %% [markdown]
# ### 다중 출력 회귀 모델 이용

# %%
class InputExample(object):
    """
    A single training/test example for simple sequence classification.
    """
    def __init__(self, guid, text_a, text_b, label):
        self.guid = guid
        self.text_a = text_a
        self.text_b = text_b
        self.label = label

    def __repr__(self):
        return str(self.to_json_string())

    def to_dict(self):
        """Serializes this instance to a Python dictionary."""
        output = copy.deepcopy(self.__dict__)
        return output

    def to_json_string(self):
        """Serializes this instance to a JSON string."""
        return json.dumps(self.to_dict(), indent=2, sort_keys=True) + "\n"

# %%
class InputFeatures(object):
    """A single set of features of data."""

    def __init__(self, input_ids, attention_mask, token_type_ids, label):
        self.input_ids = input_ids
        self.attention_mask = attention_mask
        self.token_type_ids = token_type_ids
        self.label = label

    def __repr__(self):
        return str(self.to_json_string())

    def to_dict(self):
        """Serializes this instance to a Python dictionary."""
        output = copy.deepcopy(self.__dict__)
        return output

    def to_json_string(self):
        """Serializes this instance to a JSON string."""
        return json.dumps(self.to_dict(), indent=2, sort_keys=True) + "\n"

# %%
class WellnessProcessor(object):
    """Processor for the Wellness data set """
    def __init__(self, args):
        self.args = args

    def get_labels(self):
        label_list = list(range(19))
        label_list = list(map(str, label_list)) 
        return label_list 

    @classmethod
    def _read_file(cls, input_file):
        """
        Reads a tab separated value file (csv).
        f: data/wellness/Wellness_Conversation_intent_train.tsv 
        """
        with open(input_file, "r", encoding="utf-8") as f:
            lines = []
            for line in f:
                tmp = line.strip(',') 
                lines.append(tmp[:-1]) 
            return lines

    def _create_examples(self, lines, set_type):
        """Creates examples for the training and dev sets."""
        examples = []
        for (i, line) in enumerate(lines[1:]):
            line = line.split("\t")
            guid = "%s-%s" % (set_type, i)
            text_a = line[2]
            label = line[3]
            examples.append(InputExample(guid=guid, text_a=text_a, text_b=None, label=label))
        return examples

    def get_examples(self, mode):
        """
        Args:
            mode: train, dev, test
        """
        file_to_read = None
        if mode == "train":
            file_to_read = self.args['train_file']
        elif mode == "dev":
            file_to_read = self.args['dev_file']
        elif mode == "test":
            file_to_read = self.args['test_file']

        return self._create_examples(
            self._read_file(file_to_read), mode
        )

# %%
def seq_cls_convert_examples_to_features(args, examples, tokenizer, max_length, task):
    processor = WellnessProcessor(args)
    label_list = processor.get_labels()
    output_mode = "regression"
    label_map = {label: i for i, label in enumerate(label_list)}

    def label_from_example(example):
        if output_mode == "classification":
            return label_map[example.label]
        elif output_mode == "regression":
            return float(example.label)
        
    labels = [label_from_example(example) for example in examples]
    batch_encoding = tokenizer.batch_encode_plus(
        [(example.text_a, example.text_b) for example in examples],
        max_length=max_length,
        padding="max_length",
        add_special_tokens=True,
        truncation=True,
    )

    features = []
    for i in range(len(examples)):
        inputs = {k: batch_encoding[k][i] for k in batch_encoding}
        if "token_type_ids" not in inputs:
            inputs["token_type_ids"] = [0] * len(inputs["input_ids"])  # For xlm-roberta
        feature = InputFeatures(**inputs, label=labels[i])
        features.append(feature)
    return features

# %%
def seq_cls_load_and_cache_examples(args, tokenizer, mode):
    processor = WellnessProcessor(args)   
    output_mode = "regression" 
    # Load data features from cache or dataset file

    if mode == "train":
        examples = processor.get_examples("train")
    elif mode == "dev":
        examples = processor.get_examples("dev")
    elif mode == "test":
        examples = processor.get_examples("test")
    else:
        raise ValueError("For mode, only train, dev, test is avaiable")

    features = seq_cls_convert_examples_to_features(
            args, examples, tokenizer, max_length=args['max_seq_len'], task='wellness'
      )
    
    # Convert to Tensors and build dataset
    all_input_ids = torch.tensor([f.input_ids for f in features], dtype=torch.long)
    all_attention_mask = torch.tensor([f.attention_mask for f in features], dtype=torch.long)
    all_token_type_ids = torch.tensor([f.token_type_ids for f in features], dtype=torch.long)
    if output_mode == "classification":
        all_labels = torch.tensor([f.label for f in features], dtype=torch.long)
    elif output_mode == "regression":
        all_labels = torch.tensor([f.label for f in features], dtype=torch.float)

    dataset = TensorDataset(all_input_ids, all_attention_mask, all_token_type_ids, all_labels)
    return dataset

# %%
def set_seed(args):
    random.seed(args['seed'])
    np.random.seed(args['seed'])
    torch.manual_seed(args['seed'])
    if not args['no_cuda'] and torch.cuda.is_available():
        torch.cuda.manual_seed_all(args['seed'])

# %%
processor = WellnessProcessor(config)
labels = processor.get_labels()
# labels

# %%
config2 = ElectraConfig.from_pretrained(   # ElectraConfig.from_pretrained
        config['model_name_or_path'],
        num_labels = 19,   # args.task: wellness, num_labels = 19 
        id2label={str(i): label for i, label in enumerate(labels)},   # labels: ['0', '1', '2', ... ,'18']
        label2id={label: i for i, label in enumerate(labels)},
)

# config2

# %%
tokenizer = ElectraTokenizer.from_pretrained(   # model_type: koelectra-base, ElectraTokenizer 
    config['model_name_or_path'],
    do_lower_case = config['do_lower_case'],
)

model = ElectraForSequenceClassification.from_pretrained(
    config['model_name_or_path'],
    config=config2
)
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/423M [00:00<?, ?B/s]
# Some weights of the model checkpoint at monologg/koelectra-base-discriminator were not used when initializing ElectraForSequenceClassification: ['discriminator_predictions.dense.bias', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense.weight']
# - This IS expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at monologg/koelectra-base-discriminator and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
config['device'] = "cuda" if torch.cuda.is_available() and not config['no_cuda'] else "cpu"
model.to(config['device'])
# Out:
# ElectraForSequenceClassification(
#   (electra): ElectraModel(
#     (embeddings): ElectraEmbeddings(
#       (word_embeddings): Embedding(32200, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): ElectraEncoder(
#       (layer): ModuleList(
#         (0): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): ElectraClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=19, bias=True)
#   )
# )

# %%
def calc_accuracy(X,Y):
    # print('acc:', len(X), len(Y), type(X), type(Y))
    max_vals, max_indices = torch.max(X, 1)
    # print('acc2:', max_vals, max_indices)
    train_acc = (max_indices == Y).sum().data.cpu().numpy()/max_indices.size()[0]
    return train_acc

# %%
def simple_accuracy(labels, preds):
    return (labels == preds).mean()

def acc_score(labels, preds):
    return {
        "acc": simple_accuracy(labels, preds),
    }

def pearson_and_spearman(labels, preds):
    pearson_corr = pearsonr(preds, labels)[0]
    spearman_corr = spearmanr(preds, labels)[0]
    return {
        "pearson": pearson_corr,
        "spearmanr": spearman_corr,
        "corr": (pearson_corr + spearman_corr) / 2,
    }

def f1_pre_rec(labels, preds, is_ner=True):
    if is_ner:
        return {
            "precision": seqeval_metrics.precision_score(labels, preds, suffix=True),
            "recall": seqeval_metrics.recall_score(labels, preds, suffix=True),
            "f1": seqeval_metrics.f1_score(labels, preds, suffix=True),
        }
    else:
        return {
            "precision": sklearn_metrics.precision_score(labels, preds, average="macro"),
            "recall": sklearn_metrics.recall_score(labels, preds, average="macro"),
            "f1": sklearn_metrics.f1_score(labels, preds, average="macro"),
        }

# %%
def train(args, model, train_dataset, val_dataset=None, test_dataset=None):
    train_acc_50 = []
    train_sampler = RandomSampler(train_dataset)
    train_dataloader = DataLoader(train_dataset, sampler=train_sampler, batch_size=args['train_batch_size'])
    eval_sampler = SequentialSampler(test_dataset)
    eval_dataloader = DataLoader(test_dataset, sampler=eval_sampler, batch_size=args['eval_batch_size'])

    eval_loss = 0.0
    nb_eval_steps = 0
    eval_acc_50 = []

    t_total = len(train_dataloader) // args['gradient_accumulation_steps'] * args['num_train_epochs']

    # Prepare optimizer and schedule (linear warmup and decay)
    no_decay = ['bias', 'LayerNorm.weight']
    optimizer_grouped_parameters = [
        {'params': [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)],
         'weight_decay': args['weight_decay']},
        {'params': [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)], 'weight_decay': 0.0}
    ]
    optimizer = AdamW(optimizer_grouped_parameters, lr=args['learning_rate'], eps=args['adam_epsilon'])
    scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=int(t_total * args['warmup_proportion']), num_training_steps=t_total)
    global_step = 0
    tr_loss = 0.0

    model.zero_grad()
    mb = master_bar(range(int(args['num_train_epochs'])))
    for epoch in mb:
        train_acc = 0.0
        eval_acc = 0.0
        epoch_iterator = progress_bar(train_dataloader, parent=mb)
        for step, batch in enumerate(epoch_iterator):
            model.train()
            batch = tuple(t.to(args['device']) for t in batch)
            inputs = {
                "input_ids": batch[0],
                "attention_mask": batch[1],
                "token_type_ids": batch[2],
                "labels": batch[3]
            }
            outputs = model(**inputs)
            loss = outputs[0]
            loss.backward()
            tr_loss += loss.item()
            train_acc += calc_accuracy(outputs[1], batch[3])
            # print(f'train_acc: {train_acc / (step + 1)}')
            if (step + 1) % args['gradient_accumulation_steps'] == 0 or (
                    len(train_dataloader) <= args['gradient_accumulation_steps']
                    and (step + 1) == len(train_dataloader)
            ):
                torch.nn.utils.clip_grad_norm_(model.parameters(), args['max_grad_norm'])
                optimizer.step()
                scheduler.step()
                model.zero_grad()
                global_step += 1
                
                if args['logging_steps'] > 0 and global_step % args['logging_steps'] == 0:
                    if args['evaluate_test_during_training']:
                        evaluate(args, model, test_dataset, "test", global_step)
                    else:
                        evaluate(args, model, dev_dataset, "dev", global_step)
        mb.write("Epoch {} done".format(epoch + 1))
        train_acc_50.append(train_acc / (step + 1))   

        for batch in progress_bar(eval_dataloader):
            model.eval()
            batch = tuple(t.to(args['device']) for t in batch)

            with torch.no_grad():
                inputs = {
                    "input_ids": batch[0],
                    "attention_mask": batch[1],
                    "token_type_ids": batch[2],
                    "labels": batch[3]
                }
                outputs = model(**inputs)
                tmp_eval_loss, logits = outputs[:2]
                eval_loss += tmp_eval_loss.mean().item()
                eval_acc += calc_accuracy(outputs[1], batch[3]) 

            nb_eval_steps += 1
        eval_loss = eval_loss / nb_eval_steps
        eval_acc_50.append(eval_acc / (nb_eval_steps + 1))

    return train_acc_50, eval_acc_50

# %%
def compute_metrics(task_name, labels, preds):
    assert len(preds) == len(labels)
    return acc_score(labels, preds)

# %%
train_dataset = seq_cls_load_and_cache_examples(config, tokenizer, mode="train") if config['train_file'] else None
dev_dataset = seq_cls_load_and_cache_examples(config, tokenizer, mode="dev") if config['dev_file'] else None
test_dataset = seq_cls_load_and_cache_examples(config, tokenizer, mode="test") if config['test_file'] else None

if dev_dataset == None:
    config['evaluate_test_during_training'] = True  # If there is no dev dataset, only use testset

if config['do_train']:
    train_acc, test_acc = train(config, model, train_dataset, dev_dataset, test_dataset)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/10 00:00&lt;?]
#     </div>
#
#
#
#     <div>
#       <progress value='0' class='' max='299' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/299 00:00&lt;?]
#     </div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_11311/97804554.py in <module>
#       7
#       8 if config['do_train']:
# ----> 9     train_acc, test_acc = train(config, model, train_dataset, dev_dataset, test_dataset)
#
# /tmp/ipykernel_11311/1543330516.py in train(args, model, train_dataset, val_dataset, test_dataset)
#      39                 "labels": batch[3]
#      40             }
# ---> 41             outputs = model(**inputs)
#      42             loss = outputs[0]
#      43             loss.backward()
#
# ~/anaconda3/envs/chatbot/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# TypeError: forward() got an unexpected keyword argument 'labels'
